# %%
# RUN THIS CELL FIRST!

import albumentations as A
import argparse
import cv2
import numpy as np
import os
import pandas as pd
import random
import re
import shutil
import torchvision.transforms as transforms
import xml.dom.minidom
import zipfile
from matplotlib import pyplot as plt
from PIL import Image
from PIL import ImageEnhance
from xml.dom.minidom import parse

# %%
# ---------------PARAMS------------------
root_dst_path = r'/root/yolov5/dataset/'
imgDst = f'/root/yolov5/dataset/images/'
annoDst = f'/root/yolov5/dataset/annotation/'
imgPath = r'/root/CMDI_data/image/'
annoPath = r'/root/CMDI_data/xml/'
imgDst = f'/root/yolov5/dataset/images/'
annoDst = f'/root/yolov5/dataset/annotation/'
txtSavePath = r'/root/partitionSet/'
txtlist = ['BBU3900', 'FSIH', 'B8300', 'Airscale', 'BBU3910', 'BB6648', 'BBU5900', 'BB6630', 'V9200']
partitionSavePath = txtSavePath + 'partition/'
partitionSet = [partitionSavePath + 'set1.txt', 
                partitionSavePath + 'set2.txt',  
                partitionSavePath + 'set3.txt',  
                partitionSavePath + 'set4.txt',  
                partitionSavePath + 'set5.txt']
# ---------------------------------------

# clear folders
def clear(folders):
    for kind in folders:
        filepath = root_dst_path + kind
        shutil.rmtree(filepath)
        os.mkdir(filepath)

def doAug(imgName, annoName, newImgName, newAnnoName):
    t = transform()
    t.open(imgName, annoName)
    if times > 20: t.augment_high()
    else: t.augment_low()
    t.close(newImgName, newAnnoName)

class transform:
    def __init__(self):
        """
        init
        :param img：img图像（路径）
        :param image：img图像（图像本身）
        :param xml: xml文档（路径）
        :param bboxes: xml中bbox
        """
        self.bboxes = [] # [xmin, ymin, xmax, ymax, type]
        self.is_opened = False
        
    def open(self, img, xml):
        """
        打开img和xml
        :param img：图像文件
        :param xml: xml文件
        :return:
        """
        self.is_opened = True

        #读取img
        self.img = img
        self.image = cv2.cvtColor(cv2.imread(self.img), cv2.COLOR_BGR2RGB)
        # 读取xml
        self.xml = xml
        tree = parse(self.xml)
        # 文档根元素
        root = tree.documentElement
        # 宽度，高度
        self.width = int(root.getElementsByTagName("width")[0].childNodes[0].data)
        self.height = int(root.getElementsByTagName("height")[0].childNodes[0].data)
        # 遍历每一个对象
        objs = root.getElementsByTagName("object")
        for obj in objs:
            name = obj.getElementsByTagName("name")[0].childNodes[0].data
            if name == '接地' or name == '接地线':
                continue
            box = obj.getElementsByTagName("bndbox")[0]
            xmin = int(box.getElementsByTagName("xmin")[0].childNodes[0].data)
            xmax = int(box.getElementsByTagName("xmax")[0].childNodes[0].data)
            ymin = int(box.getElementsByTagName("ymin")[0].childNodes[0].data)
            ymax = int(box.getElementsByTagName("ymax")[0].childNodes[0].data)
            typ = obj.getElementsByTagName("type")[0].childNodes[0].data
            self.bboxes.append([xmin, ymin, xmax, ymax, typ])

    def close(self, imgtarget='', xmltarget=''):
        """
        关闭xml，并将结果写入
        :param target: 写入的目标文件名，留空则写回原文件
        :return:
        """
        if imgtarget == '':
            imgtarget = self.img
        if xmltarget == '':
            xmltarget = self.xml
        self.is_opened = False

        # 保存图像
        cv2.imwrite(imgtarget, cv2.cvtColor(self.image, cv2.COLOR_RGB2BGR), [int(cv2.IMWRITE_JPEG_QUALITY), 100])
        # 读取xml文本
        tree = parse(self.xml)
        # 文档根元素
        root = tree.documentElement
        # 宽度，高度
        root.getElementsByTagName("width")[0].childNodes[0].data = str(np.size(self.image, 1))
        root.getElementsByTagName("height")[0].childNodes[0].data = str(np.size(self.image, 0))
        # 遍历每一个对象
        objs = root.getElementsByTagName("object")
        i = 0
        for obj in objs:
            name = obj.getElementsByTagName("name")[0].childNodes[0].data
            if name == '接地' or name == '接地线':
                continue
            if i < len(self.bboxes):
                elements = self.bboxes[i]
                box = obj.getElementsByTagName("bndbox")[0]
                assert elements[0] < elements[2] and elements[1] < elements[3], print(self.xml)
                box.getElementsByTagName("xmin")[0].childNodes[0].data = str(int(elements[0]))
                box.getElementsByTagName("ymin")[0].childNodes[0].data = str(int(elements[1]))
                box.getElementsByTagName("xmax")[0].childNodes[0].data = str(int(elements[2]))
                box.getElementsByTagName("ymax")[0].childNodes[0].data = str(int(elements[3]))
                obj.getElementsByTagName("type")[0].childNodes[0].data = str(elements[4])
            else: obj.parentNode.removeChild(obj)
            i += 1
        with open(xmltarget, 'w') as f:
            # 缩进 - 换行 - 编码
            tree.writexml(f, addindent='  ', encoding='utf-8')
        
    def __str__(self):
        assert self.is_opened
        return str(self.points)
    
    def augment_low(self): 
        transform = A.Compose([
                    # image-wise aug
                    A.Flip(p=0.5),
                    A.RandomRotate90(p=0.5),
                    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=10, p=0.5),
                    A.ImageCompression(quality_lower=75, quality_upper=100, p=1),
                    # pixel-wise aug
                    A.OneOf([
                        A.ISONoise(),
                        A.GaussNoise(),
                    ], p=1),
                    A.MotionBlur(p=0.2),
                    A.HueSaturationValue(p=0.5),
                    A.RandomBrightnessContrast(brightness_limit=0.1, p=0.5),
                    ], bbox_params=A.BboxParams(format='pascal_voc', min_visibility=0.5))
        transformed = transform(image=self.image, bboxes=self.bboxes)
        dropout = A.CoarseDropout(max_holes=10, max_height=50, max_width=50, p=0.1)
        do = dropout(image=transformed['image'])
        self.image = do['image']
        self.bboxes = transformed['bboxes']
        
    def augment_high(self): 
        transform = A.Compose([
                    # image-wise aug
                    A.Flip(p=0.5),
                    A.RandomRotate90(p=0.5),
                    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=20, p=0.5),
                    A.ImageCompression(quality_lower=60, quality_upper=100, p=1),
                    # pixel-wise aug
                    A.OneOf([
                        A.ISONoise(),
                        A.GaussNoise(),
                    ], p=1),
                    A.MotionBlur(p=0.5),
                    A.HueSaturationValue(p=1),
                    A.RandomBrightnessContrast(p=1),
                    ], bbox_params=A.BboxParams(format='pascal_voc', min_visibility=0.5))
        transformed = transform(image=self.image, bboxes=self.bboxes)
        dropout = A.CoarseDropout(max_holes=10, max_height=50, max_width=50, p=0.4)
        do = dropout(image=transformed['image'])
        self.image = do['image']
        self.bboxes = transformed['bboxes']

# %%
# classify image-annotation pairs according to their devices
count = 0

file_BBU3900 = open(txtsavepath + 'BBU3900.txt', 'w')
file_FSIH = open(txtsavepath + 'FSIH.txt', 'w')
file_B8300 = open(txtsavepath + 'B8300.txt', 'w')
file_Airscale = open(txtsavepath + 'Airscale.txt', 'w')
file_BBU3910 = open(txtsavepath + 'BBU3910.txt', 'w')
file_BB6648 = open(txtsavepath + 'BB6648.txt', 'w')
file_BBU5900 = open(txtsavepath + 'BBU5900.txt', 'w')
file_BB6630 = open(txtsavepath + 'BB6630.txt', 'w')
file_V9200 = open(txtsavepath + 'V9200.txt', 'w')

imglist = os.listdir(imgPath)
for image in imglist:
    imgname = imgPath + image
    annoname = annoPath + image.replace('.jpg','.xml')
    if annoname == f'/root/CMDI_data/xml/.ipynb_checkpoints': continue
    
    dom = xml.dom.minidom.parse(annoname)
    collection = dom.documentElement
    objectlist = collection.getElementsByTagName('object')
    
    devices = []
    for obj in objectlist:
        if obj.getElementsByTagName('name')[0].childNodes[0].data == '接地': continue
        if obj.getElementsByTagName('name')[0].childNodes[0].data == '接地线': continue
        type = obj.getElementsByTagName('type')[0].childNodes[0].data
        devices.append(type)    
    print(image, set(devices), len(devices))
    
    if '华为BBU3900' in devices:
        file_BBU3900.write(imgname + '\n')
        count += 1
    elif '诺基亚 FSIH' in devices:
        file_FSIH.write(imgname + '\n')
        count += 1
    elif '中兴B8300' in devices:
        file_B8300.write(imgname + '\n')
        count += 1
    elif '诺基亚 Airscale' in devices:
        file_Airscale.write(imgname + '\n')
        count += 1
    elif '华为BBU3910' in devices:
        file_BBU3910.write(imgname + '\n')
        count += 1
    elif '爱立信BB6648' in devices:
        file_BB6648.write(imgname + '\n')
        count += 1
    elif '华为BBU5900' in devices:
        file_BBU5900.write(imgname + '\n')
        count += 1
    elif '爱立信BB6630' in devices:
        file_BB6630.write(imgname + '\n')
        count += 1
    elif '中兴V9200' in devices:
        file_V9200.write(imgname + '\n')
        count += 1
        
assert count == len(os.listdir(imgPath))
file_BBU3900.close()
file_FSIH.close()
file_B8300.close()
file_Airscale.close()
file_BBU3910.close()
file_BB6648.close()
file_BBU5900.close()
file_BB6630.close()
file_V9200.close()
# Out:
# 100000263_b11uj182.jpg {'爱立信BB6630'} 2
# 100000263_gc4iae2b.jpg {'爱立信BB6630'} 1
# 100000263_4140avcf.jpg {'中兴V9200'} 1
# 100000263_2hv48jxi.jpg {'华为BBU3910'} 1
# 100000263_p6uc632e.jpg {'中兴V9200'} 1
# 100000263_un4c6677.jpg {'爱立信BB6648'} 1
# 100000263_a3v81n4p.jpg {'华为BBU3910'} 1
# 100000263_g4hy5572.jpg {'华为BBU5900'} 1
# 100000263_v1fmgw7w.jpg {'中兴V9200'} 1
# 100000263_j3ct28q5.jpg {'爱立信BB6630'} 1
# 100000263_18li3y4f.jpg {'华为BBU5900'} 1
# 100000263_36u445ce.jpg {'华为BBU5900'} 1
# 100000263_45v4p81s.jpg {'爱立信BB6630'} 1
# 100000263_71k60d55.jpg {'爱立信BB6630'} 1
# 100000263_6m4u2a4b.jpg {'爱立信BB6630'} 2
# 100000263_5ee74156.jpg {'华为BBU5900'} 1
# 100000263_0nf2827i.jpg {'华为BBU5900'} 1
# 100000263_t41qdm3a.jpg {'华为BBU5900'} 1
# 100000263_1666m8ha.jpg {'中兴V9200'} 1
# 100000263_oal74s6t.jpg {'华为BBU5900'} 1
# 100000263_j5gt71a0.jpg {'华为BBU5900'} 1
# 100000263_607bf6k4.jpg {'爱立信BB6630'} 1
# 100000263_34r6wigd.jpg {'中兴V9200'} 1
# 100000263_3s88opn5.jpg {'爱立信BB6630'} 3
# 100000263_bu7w2po7.jpg {'爱立信BB6630'} 2
# 100000263_a638y87w.jpg {'中兴V9200'} 1
# 100000263_4f324h6e.jpg {'华为BBU5900'} 1
# 100000263_5h0t42ke.jpg {'华为BBU5900'} 1
# 100000263_jj84381w.jpg {'华为BBU5900'} 1
# 100000263_an8cn0a7.jpg {'华为BBU5900'} 1
# 100000263_6ob61r63.jpg {'爱立信BB6630'} 1
# 100000263_071vd2qf.jpg {'中兴V9200'} 1
# 100000263_pxjwta7i.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_0aythokb.jpg {'中兴V9200'} 1
# 100000263_5gilq4ai.jpg {'中兴V9200'} 1
# 100000263_mc3a7x52.jpg {'中兴V9200'} 1
# 100000263_h1c873j2.jpg {'中兴V9200'} 1
# 100000263_nefpfb7a.jpg {'爱立信BB6630'} 3
# 100000263_r07f38rt.jpg {'爱立信BB6630'} 1
# 100000263_8hwho1wk.jpg {'中兴V9200'} 1
# 100000263_yf71kbiw.jpg {'爱立信BB6630'} 1
# 100000263_we786iv0.jpg {'中兴V9200'} 1
# 100000263_b5m1n21b.jpg {'爱立信BB6630'} 1
# 100000263_81v5210c.jpg {'爱立信BB6630'} 2
# 100000263_rgmrpusm.jpg {'中兴V9200'} 1
# 100000263_2kp7tk35.jpg {'华为BBU5900'} 1
# 100000263_nelr7t21.jpg {'中兴V9200'} 1
# 100000263_m471yxhw.jpg {'中兴V9200'} 1
# 100000263_grl5it13.jpg {'中兴V9200'} 1
# 100000263_vi6wey8s.jpg {'中兴V9200'} 1
# 100000263_t48ps01q.jpg {'中兴V9200'} 1
# 100000263_hgvq18by.jpg {'中兴V9200'} 1
# 100000263_1yoyv72x.jpg {'华为BBU5900'} 1
# 100000263_3f468av4.jpg {'爱立信BB6630'} 1
# 100000263_0t2y011w.jpg {'爱立信BB6630'} 1
# 100000263_tm07dk4w.jpg {'中兴V9200'} 1
# 100000263_0scf333i.jpg {'爱立信BB6630'} 1
# 100000263_et161a0y.jpg {'中兴V9200'} 1
# 100000263_4jhuq0r5.jpg {'华为BBU5900'} 1
# 100000263_sjuf3o17.jpg {'中兴V9200'} 1
# 100000263_w282t1u3.jpg {'华为BBU5900'} 1
# 100000263_h42l4h50.jpg {'中兴V9200'} 1
# 100000263_cj16m8x7.jpg {'华为BBU3910', '华为BBU5900'} 3
# 100000263_r624o6uu.jpg {'中兴V9200'} 1
# 100000263_48nf57m1.jpg {'中兴V9200'} 1
# 100000263_gv6hlq3p.jpg {'爱立信BB6630'} 2
# 100000263_l03g24e8.jpg {'华为BBU5900'} 1
# 100000263_1bj680h8.jpg {'爱立信BB6630'} 1
# 100000263_j036174i.jpg {'华为BBU5900'} 1
# 100000263_d13c431y.jpg {'中兴V9200'} 1
# 100000263_7t1lv6l8.jpg {'中兴V9200'} 1
# 100000263_26751sq7.jpg {'中兴V9200'} 1
# 100000263_a047287i.jpg {'爱立信BB6630'} 2
# 100000263_sg1stl4f.jpg {'华为BBU5900'} 1
# 100000263_kw403e10.jpg {'中兴V9200'} 3
# 100000263_os0v31jy.jpg {'中兴V9200'} 1
# 100000263_tst2fwcb.jpg {'中兴V9200'} 1
# 100000263_qgt38v76.jpg {'中兴V9200'} 1
# 100000263_gy2w37ms.jpg {'爱立信BB6630'} 1
# 100000263_n0002wal.jpg {'爱立信BB6630'} 2
# 100000263_j057yc6w.jpg {'爱立信BB6630'} 6
# 100000263_y866b773.jpg {'中兴V9200'} 1
# 100000263_4ui0x84n.jpg {'华为BBU5900'} 1
# 100000263_h3la7812.jpg {'华为BBU5900'} 1
# 100000263_x25q77f2.jpg {'爱立信BB6630'} 1
# 100000263_826l3c35.jpg {'中兴V9200'} 1
# 100000263_w848f4x7.jpg {'中兴V9200'} 1
# 100000263_uuf521yi.jpg {'爱立信BB6648'} 1
# 100000263_62yq232u.jpg {'华为BBU5900'} 1
# 100000263_81qv2b56.jpg {'华为BBU5900', '华为BBU3900'} 2
# 100000263_xw43qgpm.jpg {'爱立信BB6630'} 1
# 100000263_e614l0cx.jpg {'华为BBU5900'} 1
# 100000263_580h4c12.jpg {'爱立信BB6630'} 1
# 100000263_8o51umuo.jpg {'爱立信BB6630'} 2
# 100000263_4kvtwu16.jpg {'中兴V9200'} 1
# 100000263_8ikkxneg.jpg {'爱立信BB6630'} 1
# 100000263_kvq4qdbh.jpg {'中兴V9200'} 1
# 100000263_eb3d7u07.jpg {'华为BBU5900'} 1
# 100000263_jthv56en.jpg {'中兴V9200'} 1
# 100000263_ed4a31eo.jpg {'华为BBU5900'} 1
# 100000263_ey8b7c2x.jpg {'中兴V9200'} 2
# 100000263_018rl5i1.jpg {'爱立信BB6630'} 2
# 100000263_084w14e2.jpg {'华为BBU3910'} 1
# 100000263_7pc66a02.jpg {'爱立信BB6630'} 2
# 100000263_8k3nflq2.jpg {'中兴V9200'} 1
# 100000263_510n183o.jpg {'中兴V9200'} 1
# 100000263_2c2r8s24.jpg {'中兴V9200'} 1
# 100000263_t5tj0u5t.jpg {'中兴V9200'} 1
# 100000263_i7p26370.jpg {'中兴V9200'} 1
# 100000263_2vch11d5.jpg {'华为BBU5900'} 1
# 100000263_u3725rn2.jpg {'华为BBU3910'} 1
# 100000263_p6040766.jpg {'华为BBU5900'} 1
# 100000263_54sul8cf.jpg {'中兴V9200'} 1
# 100000263_sn656qe8.jpg {'爱立信BB6630'} 1
# 100000263_l3216g6m.jpg {'中兴V9200'} 1
# 100000263_8hyikf2b.jpg {'中兴V9200'} 1
# 100000263_buq62o1m.jpg {'中兴B8300'} 1
# 100000263_8s0p4i6y.jpg {'中兴V9200'} 1
# 100000263_8428sjvx.jpg {'华为BBU5900'} 1
# 100000263_c210v1x3.jpg {'中兴V9200'} 1
# 100000263_ql5s8f6r.jpg {'爱立信BB6630'} 1
# 100000263_p8r4x7hd.jpg {'爱立信BB6630'} 1
# 100000263_x4j40hw4.jpg {'中兴V9200'} 1
# 100000263_uth3cmht.jpg {'中兴V9200'} 1
# 100000263_41p60y53.jpg {'爱立信BB6630'} 3
# 100000263_4q4i1nqh.jpg {'中兴V9200'} 1
# 100000263_k6w3o0y5.jpg {'中兴V9200'} 2
# 100000263_gsyv8ncp.jpg {'爱立信BB6648'} 1
# 100000263_yl5w187y.jpg {'爱立信BB6630'} 3
# 100000263_r2x3xagv.jpg {'爱立信BB6630'} 1
# 100000263_l4wxudoi.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_54a18s4i.jpg {'华为BBU5900'} 1
# 100000263_5248212f.jpg {'爱立信BB6630'} 2
# 100000263_1yyxa542.jpg {'中兴V9200'} 1
# 100000263_7p85x22d.jpg {'中兴V9200'} 1
# 100000263_1ov7uri8.jpg {'爱立信BB6630'} 1
# 100000263_r884psh1.jpg {'中兴V9200'} 1
# 100000263_501p7745.jpg {'华为BBU5900'} 1
# 100000263_3q54484b.jpg {'中兴V9200'} 1
# 100000263_aifcp75o.jpg {'中兴V9200'} 1
# 100000263_u6c0mn08.jpg {'中兴B8300'} 1
# 100000263_53vc85hw.jpg {'华为BBU5900'} 1
# 100000263_6461ym78.jpg {'爱立信BB6630'} 1
# 100000263_swvob711.jpg {'华为BBU5900'} 1
# 100000263_18782a6y.jpg {'爱立信BB6630'} 1
# 100000263_bdc505u7.jpg {'中兴V9200'} 1
# 100000263_15rbdo33.jpg {'华为BBU5900'} 1
# 100000263_8c7qq8n5.jpg {'华为BBU5900'} 1
# 100000263_12urk6tb.jpg {'中兴V9200'} 1
# 100000263_6ikkxu5q.jpg {'华为BBU5900'} 1
# 100000263_b7li0h6h.jpg {'爱立信BB6630'} 1
# 100000263_120rd8w4.jpg {'中兴V9200'} 1
# 100000263_87530n0i.jpg {'中兴V9200'} 1
# 100000263_32pbk26v.jpg {'华为BBU5900'} 1
# 100000263_q73v6e6j.jpg {'爱立信BB6630'} 1
# 100000263_l33li2l6.jpg {'爱立信BB6630'} 2
# 100000263_05ihkojt.jpg {'华为BBU5900'} 1
# 100000263_83hw032c.jpg {'爱立信BB6630'} 1
# 100000263_j8y237s4.jpg {'中兴V9200', '诺基亚 FSIH'} 2
# 100000263_320w17k4.jpg {'华为BBU5900'} 1
# 100000263_trhet35y.jpg {'中兴V9200'} 1
# 100000263_0gn4o30q.jpg {'中兴V9200'} 1
# 100000263_66q8ukn7.jpg {'中兴V9200'} 1
# 100000263_sg3ejak0.jpg {'华为BBU5900'} 1
# 100000263_fluy4crr.jpg {'中兴V9200'} 1
# 100000263_we1i74jd.jpg {'华为BBU3910', '诺基亚 Airscale', '华为BBU5900'} 4
# 100000263_v0nre5e3.jpg {'华为BBU5900'} 1
# 100000263_3rapgcb2.jpg {'华为BBU5900'} 1
# 100000263_dxq114nd.jpg {'爱立信BB6630'} 1
# 100000263_l54g21r0.jpg {'中兴V9200'} 1
# 100000263_226q47j1.jpg {'诺基亚 Airscale', '爱立信BB6630'} 2
# 100000263_swuoo6y4.jpg {'中兴V9200'} 1
# 100000263_xxiu6x80.jpg {'中兴V9200'} 1
# 100000263_773kr26p.jpg {'华为BBU5900'} 1
# 100000263_n4i7dpua.jpg {'爱立信BB6630'} 2
# 100000263_35wq2bgb.jpg {'爱立信BB6630'} 1
# 100000263_388nne8f.jpg {'中兴V9200'} 1
# 100000263_0k26au33.jpg {'中兴V9200'} 1
# 100000263_5q4s18f3.jpg {'爱立信BB6630'} 1
# 100000263_j873284p.jpg {'爱立信BB6630'} 1
# 100000263_s06d02n4.jpg {'爱立信BB6630'} 1
# 100000263_3p0eyt0i.jpg {'中兴V9200'} 1
# 100000263_v08714ji.jpg {'华为BBU5900'} 1
# 100000263_v5143jj3.jpg {'中兴V9200'} 1
# 100000263_a4gj00pt.jpg {'爱立信BB6630'} 1
# 100000263_lp8c3173.jpg {'中兴V9200'} 1
# 100000263_6a130piq.jpg {'爱立信BB6648'} 2
# 100000263_c41qg07k.jpg {'中兴V9200'} 1
# 100000263_2tv65o65.jpg {'华为BBU5900'} 1
# 100000263_mnf2h820.jpg {'华为BBU5900'} 1
# 100000263_1m1v40d8.jpg {'华为BBU5900'} 1
# 100000263_5lkf2p3j.jpg {'华为BBU5900'} 1
# 100000263_556bk6l5.jpg {'中兴V9200'} 1
# 100000263_b4ee3vak.jpg {'中兴V9200', '中兴B8300'} 2
# 100000263_1pitippi.jpg {'华为BBU5900'} 1
# 100000263_vo76wh08.jpg {'华为BBU5900'} 1
# 100000263_h3f6w3a1.jpg {'爱立信BB6630'} 1
# 100000263_e32687jx.jpg {'华为BBU5900'} 1
# 100000263_4aj53l3x.jpg {'华为BBU5900'} 1
# 100000263_26g602d3.jpg {'华为BBU3910'} 1
# 100000263_tpit7073.jpg {'华为BBU5900'} 1
# 100000263_8ff2kr15.jpg {'中兴V9200'} 1
# 100000263_c50rmb2k.jpg {'中兴V9200'} 1
# 100000263_6by4226k.jpg {'华为BBU5900'} 1
# 100000263_323m8hf2.jpg {'华为BBU5900'} 1
# 100000263_77i165x0.jpg {'华为BBU5900'} 1
# 100000263_s62k302f.jpg {'爱立信BB6630'} 2
# 100000263_8g6411i4.jpg {'华为BBU5900'} 1
# 100000263_754gul33.jpg {'中兴V9200'} 1
# 100000263_628244dv.jpg {'中兴V9200'} 1
# 100000263_dsc01i32.jpg {'中兴V9200'} 1
# 100000263_v358jpdb.jpg {'华为BBU5900'} 1
# 100000263_pve8466a.jpg {'华为BBU3900'} 1
# 100000263_o13pu8p2.jpg {'爱立信BB6630'} 1
# 100000263_c122brha.jpg {'爱立信BB6630'} 1
# 100000263_670roi7n.jpg {'爱立信BB6630'} 2
# 100000263_ghqn725v.jpg {'华为BBU5900'} 1
# 100000263_45h6eaaq.jpg {'爱立信BB6630'} 1
# 100000263_6l7ybt3p.jpg {'华为BBU5900'} 1
# 100000263_i0sa54rb.jpg {'爱立信BB6630'} 1
# 100000263_oxr4u81x.jpg {'中兴V9200'} 1
# 100000263_20mv8270.jpg {'华为BBU5900'} 1
# 100000263_pr510782.jpg {'华为BBU5900'} 1
# 100000263_imaswh10.jpg {'爱立信BB6630'} 1
# 100000263_j11842b4.jpg {'中兴V9200'} 1
# 100000263_31ia804g.jpg {'中兴V9200'} 1
# 100000263_7430vgs1.jpg {'爱立信BB6648'} 1
# 100000263_knb1126x.jpg {'爱立信BB6648'} 2
# 100000263_612v7125.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_v4385meo.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_57642s7p.jpg {'爱立信BB6630'} 2
# 100000263_h3bl246k.jpg {'中兴V9200'} 1
# 100000263_sw0e2868.jpg {'爱立信BB6630'} 2
# 100000263_1y7dtof1.jpg {'中兴V9200'} 1
# 100000263_3m4ba15o.jpg {'中兴V9200'} 1
# 100000263_121581jy.jpg {'中兴V9200'} 1
# 100000263_hd5gk5a1.jpg {'中兴V9200'} 1
# 100000263_es254214.jpg {'中兴V9200'} 1
# 100000263_6ig7nyr2.jpg {'中兴V9200'} 1
# 100000263_ml41p28d.jpg {'中兴V9200'} 1
# 100000263_r20050g7.jpg {'爱立信BB6630'} 1
# 100000263_872548c0.jpg {'中兴V9200'} 1
# 100000263_vnigreqv.jpg {'中兴V9200'} 1
# 100000263_don26r1o.jpg {'华为BBU5900'} 1
# 100000263_2v3hhtqm.jpg {'中兴V9200'} 1
# 100000263_2346s2my.jpg {'华为BBU5900'} 1
# 100000263_ur0r8xuk.jpg {'华为BBU5900'} 1
# 100000263_1nhe6qnv.jpg {'中兴V9200'} 1
# 100000263_mgw5058y.jpg {'爱立信BB6630'} 2
# 100000263_142ve10i.jpg {'华为BBU5900'} 1
# 100000263_u6jl8g12.jpg {'中兴B8300'} 1
# 100000263_b8g4h6j8.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_yn74wmo6.jpg {'华为BBU5900'} 1
# 100000263_p82u0nmq.jpg {'华为BBU5900'} 1
# 100000263_416583bw.jpg {'中兴V9200'} 1
# 100000263_0rl616ps.jpg {'中兴V9200'} 1
# 100000263_edfrncf1.jpg {'华为BBU5900'} 1
# 100000263_ht74426i.jpg {'华为BBU5900'} 1
# 100000263_1lu347hk.jpg {'中兴V9200'} 1
# 100000263_nw6040mj.jpg {'爱立信BB6630'} 1
# 100000263_h1mh0t21.jpg {'华为BBU5900'} 1
# 100000263_w50444vj.jpg {'华为BBU5900'} 2
# 100000263_u2vkf76j.jpg {'爱立信BB6630'} 1
# 100000263_2a1nn28r.jpg {'中兴V9200'} 1
# 100000263_8qu6u82a.jpg {'华为BBU5900'} 1
# 100000263_g3r7110g.jpg {'华为BBU5900'} 1
# 100000263_b82k77n6.jpg {'华为BBU5900'} 1
# 100000263_e3k3a26j.jpg {'华为BBU5900'} 1
# 100000263_syjhbu6c.jpg {'爱立信BB6630'} 2
# 100000263_ke121gcs.jpg {'中兴V9200'} 1
# 100000263_oh5q4k82.jpg {'中兴V9200'} 1
# 100000263_m43m371m.jpg {'爱立信BB6630'} 1
# 100000263_r70cqe6u.jpg {'中兴V9200'} 1
# 100000263_n6a85u4a.jpg {'华为BBU5900'} 1
# 100000263_674032m7.jpg {'爱立信BB6630'} 3
# 100000263_twi05175.jpg {'中兴V9200'} 1
# 100000263_bkt21gba.jpg {'华为BBU5900'} 1
# 100000263_76pl6gc0.jpg {'华为BBU5900'} 1
# 100000263_v6j0r47w.jpg {'华为BBU5900'} 1
# 100000263_c138et1i.jpg {'爱立信BB6630'} 1
# 100000263_h00mt4lk.jpg {'中兴V9200'} 1
# 100000263_py5d60xc.jpg {'爱立信BB6630'} 6
# 100000263_y1ykb236.jpg {'华为BBU5900'} 1
# 100000263_8idsaqox.jpg {'中兴V9200'} 1
# 100000263_71on8h82.jpg {'华为BBU5900'} 1
# 100000263_gy531g4i.jpg {'华为BBU5900'} 1
# 100000263_v07n2aca.jpg {'华为BBU5900'} 1
# 100000263_27k0e6b8.jpg {'爱立信BB6630'} 1
# 100000263_3h30028g.jpg {'中兴V9200'} 1
# 100000263_xfa63b52.jpg {'中兴V9200'} 1
# 100000263_3a2r80iq.jpg {'中兴V9200'} 1
# 100000263_2vswnc5w.jpg {'爱立信BB6630'} 1
# 100000263_xoxbi806.jpg {'爱立信BB6630'} 2
# 100000263_kums3m7o.jpg {'中兴V9200'} 1
# 100000263_845dej2u.jpg {'华为BBU5900'} 1
# 100000263_1o15uv57.jpg {'爱立信BB6630'} 2
# 100000263_07ywyi7w.jpg {'中兴V9200'} 1
# 100000263_fsa1p1xx.jpg {'爱立信BB6630'} 1
# 100000263_pa3o6x75.jpg {'华为BBU5900'} 1
# 100000263_h4a67482.jpg {'中兴V9200'} 1
# 100000263_84114dt2.jpg {'中兴V9200'} 1
# 100000263_7klm2qao.jpg {'爱立信BB6630'} 2
# 100000263_u52r601q.jpg {'爱立信BB6630'} 1
# 100000263_8dy0qo2w.jpg {'爱立信BB6630'} 1
# 100000263_qb6u3o02.jpg {'中兴V9200'} 1
# 100000263_21260r2y.jpg {'华为BBU5900'} 1
# 100000263_142563ge.jpg {'中兴V9200'} 1
# 100000263_px8rowa6.jpg {'华为BBU5900'} 1
# 100000263_o6g706ec.jpg {'华为BBU5900'} 1
# 100000263_tl62m5j8.jpg {'中兴V9200', '中兴B8300'} 2
# 100000263_8w327nw1.jpg {'中兴V9200'} 1
# 100000263_d4uecj07.jpg {'中兴V9200'} 1
# 100000263_j0kx6e4p.jpg {'爱立信BB6630'} 1
# 100000263_55b51nl4.jpg {'中兴V9200'} 1
# 100000263_j0o71826.jpg {'华为BBU5900'} 1
# 100000263_40h40u35.jpg {'爱立信BB6630'} 3
# 100000263_tceb4005.jpg {'华为BBU5900'} 1
# 100000263_p4m143n6.jpg {'中兴V9200'} 1
# 100000263_04ommk10.jpg {'中兴V9200'} 1
# 100000263_xp1c0u2y.jpg {'爱立信BB6630'} 3
# 100000263_30x6a18k.jpg {'爱立信BB6630'} 1
# 100000263_kmh57068.jpg {'华为BBU5900'} 1
# 100000263_aw182nma.jpg {'爱立信BB6630'} 4
# 100000263_j40s2vj3.jpg {'中兴V9200'} 1
# 100000263_gyrl64o6.jpg {'中兴V9200'} 1
# 100000263_k4f1f87b.jpg {'爱立信BB6630'} 1
# 100000263_basam1wf.jpg {'中兴V9200'} 2
# 100000263_wq13gpug.jpg {'中兴V9200'} 2
# 100000263_vo10ht8r.jpg {'华为BBU5900'} 1
# 100000263_k51opstn.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_3jufli66.jpg {'华为BBU5900'} 1
# 100000263_hqg0lge3.jpg {'中兴V9200'} 1
# 100000263_1i42tiwq.jpg {'中兴V9200'} 1
# 100000263_06xe0033.jpg {'华为BBU5900'} 1
# 100000263_4y358802.jpg {'中兴V9200'} 1
# 100000263_y565m3ac.jpg {'中兴V9200'} 1
# 100000263_8tk1m641.jpg {'华为BBU5900'} 1
# 100000263_6ldm61nf.jpg {'诺基亚 Airscale'} 1
# 100000263_vq1587ye.jpg {'爱立信BB6630'} 2
# 100000263_sqlx36kg.jpg {'爱立信BB6630'} 1
# 100000263_5e4guuql.jpg {'中兴V9200'} 1
# 100000263_17v36mx5.jpg {'中兴V9200'} 1
# 100000263_3jr0yys1.jpg {'爱立信BB6630'} 2
# 100000263_6ju0j2bx.jpg {'中兴V9200'} 1
# 100000263_18m1h5o6.jpg {'中兴V9200'} 1
# 100000263_623ay16n.jpg {'中兴V9200'} 1
# 100000263_572u1485.jpg {'华为BBU5900'} 1
# 100000263_ymuh1hdh.jpg {'中兴V9200'} 1
# 100000263_ld3h267r.jpg {'爱立信BB6630'} 1
# 100000263_00i0r0fr.jpg {'爱立信BB6630'} 1
# 100000263_he270cg2.jpg {'爱立信BB6630'} 3
# 100000263_ny244f4b.jpg {'爱立信BB6630'} 1
# 100000263_8w44q83w.jpg {'华为BBU5900'} 1
# 100000263_y4g73tmi.jpg {'华为BBU5900'} 1
# 100000263_c8648l84.jpg {'华为BBU5900'} 1
# 100000263_1333dnww.jpg {'诺基亚 Airscale', '诺基亚 FSIH'} 2
# 100000263_d0bjrbqo.jpg {'中兴V9200'} 1
# 100000263_5gbmo37d.jpg {'爱立信BB6630'} 1
# 100000263_igihej61.jpg {'华为BBU5900'} 1
# 100000263_jn6c2636.jpg {'华为BBU5900'} 1
# 100000263_t7gv7i4j.jpg {'中兴V9200'} 1
# 100000263_682h28wq.jpg {'华为BBU5900'} 1
# 100000263_p8agdv7l.jpg {'中兴V9200'} 1
# 100000263_eco847w1.jpg {'爱立信BB6630'} 3
# 100000263_58n0xlaa.jpg {'华为BBU5900'} 1
# 100000263_0b33sb74.jpg {'华为BBU5900'} 2
# 100000263_0ff00016.jpg {'中兴V9200'} 1
# 100000263_s3kqvjfu.jpg {'中兴V9200'} 1
# 100000263_y7ux5474.jpg {'华为BBU5900'} 1
# 100000263_126j3xx6.jpg {'爱立信BB6630'} 1
# 100000263_231s802a.jpg {'中兴V9200'} 1
# 100000263_32rpjds3.jpg {'华为BBU5900'} 1
# 100000263_g3445i11.jpg {'中兴V9200'} 1
# 100000263_0y82o421.jpg {'爱立信BB6630'} 1
# 100000263_urre2ok0.jpg {'华为BBU3910', '诺基亚 FSIH'} 2
# 100000263_5g54wh42.jpg {'爱立信BB6630'} 1
# 100000263_plr4tp72.jpg {'华为BBU5900'} 1
# 100000263_3k5q4bbm.jpg {'华为BBU5900'} 1
# 100000263_8p7ndiv1.jpg {'爱立信BB6630'} 1
# 100000263_7587rr6q.jpg {'中兴V9200'} 1
# 100000263_w535v844.jpg {'中兴V9200'} 1
# 100000263_c0068h37.jpg {'爱立信BB6630'} 2
# 100000263_7or7yji4.jpg {'中兴V9200'} 1
# 100000263_hb617770.jpg {'中兴V9200'} 1
# 100000263_t4nt4m8h.jpg {'中兴V9200'} 1
# 100000263_1nd4c8w8.jpg {'华为BBU5900'} 1
# 100000263_jm6v766u.jpg {'爱立信BB6630'} 1
# 100000263_6d6nk3de.jpg {'中兴V9200'} 1
# 100000263_tf12a0ee.jpg {'华为BBU5900'} 1
# 100000263_5g2736a2.jpg {'爱立信BB6630'} 1
# 100000263_cq2665v6.jpg {'中兴V9200'} 1
# 100000263_cr1kt2c0.jpg {'中兴V9200'} 1
# 100000263_l6588a0h.jpg {'华为BBU5900'} 1
# 100000263_wi21h0vi.jpg {'华为BBU5900'} 1
# 100000263_gsn1xxi0.jpg {'爱立信BB6630'} 1
# 100000263_fo6222f3.jpg {'中兴V9200'} 1
# 100000263_v3q54pcn.jpg {'中兴V9200', '中兴B8300'} 2
# 100000263_28ti5s07.jpg {'中兴V9200'} 1
# 100000263_7l35mi44.jpg {'华为BBU5900'} 1
# 100000263_jdvjmsb5.jpg {'中兴V9200'} 1
# 100000263_4p7j57hq.jpg {'中兴V9200'} 1
# 100000263_20f5pp5w.jpg {'中兴V9200'} 1
# 100000263_600le0c1.jpg {'爱立信BB6630'} 1
# 100000263_be7m1q4n.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_w1e37i62.jpg {'中兴V9200'} 1
# 100000263_ek00c3rl.jpg {'中兴V9200'} 1
# 100000263_3jdqdh8p.jpg {'爱立信BB6630'} 2
# 100000263_fras3663.jpg {'中兴V9200'} 2
# 100000263_3hbwmi31.jpg {'爱立信BB6630'} 1
# 100000263_baftmejg.jpg {'爱立信BB6630'} 1
# 100000263_lct10nrk.jpg {'诺基亚 Airscale'} 1
# 100000263_wf0qjkx7.jpg {'华为BBU5900'} 1
# 100000263_r3mq7773.jpg {'华为BBU5900'} 1
# 100000263_63et0u7c.jpg {'爱立信BB6630'} 1
# 100000263_k1p65rr7.jpg {'中兴V9200'} 1
# 100000263_dq18f41m.jpg {'华为BBU5900'} 1
# 100000263_1vf643sj.jpg {'中兴V9200'} 1
# 100000263_a0fav2c7.jpg {'爱立信BB6630'} 1
# 100000263_i8ons5y2.jpg {'爱立信BB6630'} 1
# 100000263_578c2hb5.jpg {'中兴V9200'} 1
# 100000263_86qos11f.jpg {'中兴V9200'} 1
# 100000263_5ueksq1b.jpg {'爱立信BB6630'} 1
# 100000263_x46uy58a.jpg {'华为BBU5900'} 1
# 100000263_5hdd62tr.jpg {'华为BBU5900'} 1
# 100000263_uugnsto3.jpg {'中兴V9200'} 1
# 100000263_nq60v28h.jpg {'爱立信BB6630'} 3
# 100000263_7oy06j46.jpg {'中兴V9200'} 1
# 100000263_v1w88fol.jpg {'华为BBU5900'} 1
# 100000263_38s1i78r.jpg {'华为BBU5900'} 1
# 100000263_ij8k1453.jpg {'中兴V9200'} 1
# 100000263_4gr5g4um.jpg {'中兴V9200'} 1
# 100000263_63ovc4fb.jpg {'中兴V9200'} 1
# 100000263_oj5sxoey.jpg {'中兴V9200'} 1
# 100000263_56l3w3h2.jpg {'华为BBU5900'} 1
# 100000263_ws373km3.jpg {'中兴V9200'} 1
# 100000263_6eor51jo.jpg {'华为BBU5900'} 1
# 100000263_bqs3ev14.jpg {'爱立信BB6630'} 1
# 100000263_65aw3p15.jpg {'中兴V9200'} 1
# 100000263_p7a02l8k.jpg {'华为BBU5900'} 1
# 100000263_6x6v8a26.jpg {'华为BBU5900'} 1
# 100000263_6w66qxgp.jpg {'中兴V9200'} 1
# 100000263_8u28pist.jpg {'中兴V9200'} 1
# 100000263_c24330y8.jpg {'爱立信BB6630'} 1
# 100000263_6ys12jr0.jpg {'中兴V9200'} 1
# 100000263_1u5o2s76.jpg {'华为BBU3910'} 1
# 100000263_k4ksrh7r.jpg {'爱立信BB6630'} 2
# 100000263_a2b3dakj.jpg {'华为BBU5900'} 1
# 100000263_uu1iy36u.jpg {'中兴V9200'} 1
# 100000263_u1k47r56.jpg {'华为BBU3910'} 1
# 100000263_u72e4351.jpg {'爱立信BB6630'} 1
# 100000263_wnj3450o.jpg {'爱立信BB6630'} 1
# 100000263_m7e8i74i.jpg {'中兴V9200'} 1
# 100000263_s3n1ukdu.jpg {'华为BBU5900'} 1
# 100000263_xot671xr.jpg {'华为BBU5900'} 1
# 100000263_is518165.jpg {'爱立信BB6630'} 1
# 100000263_o3e5nr3t.jpg {'华为BBU5900'} 1
# 100000263_p0m446e8.jpg {'中兴V9200'} 1
# 100000263_n3r54vy6.jpg {'诺基亚 Airscale'} 1
# 100000263_dg76rvde.jpg {'华为BBU5900'} 1
# 100000263_7xj5d2fl.jpg {'中兴V9200'} 1
# 100000263_5ne43txb.jpg {'爱立信BB6630'} 1
# 100000263_evj4t4q6.jpg {'华为BBU5900'} 1
# 100000263_6g65l00f.jpg {'华为BBU5900'} 1
# 100000263_5l7mnq7v.jpg {'华为BBU3900'} 1
# 100000263_fvktr65u.jpg {'中兴V9200'} 1
# 100000263_7r31svs0.jpg {'中兴V9200'} 1
# 100000263_2n6e88mk.jpg {'华为BBU5900'} 1
# 100000263_1205rmr7.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_dh43tb85.jpg {'爱立信BB6630'} 1
# 100000263_4ddk8b2r.jpg {'华为BBU5900'} 1
# 100000263_ge1b8g3s.jpg {'中兴V9200'} 1
# 100000263_77eyjt6w.jpg {'中兴V9200'} 1
# 100000263_ec63fr40.jpg {'华为BBU5900'} 1
# 100000263_33p2oo70.jpg {'华为BBU5900'} 1
# 100000263_74s23a43.jpg {'爱立信BB6648'} 1
# 100000263_8wk84624.jpg {'诺基亚 Airscale'} 1
# 100000263_cdor674y.jpg {'中兴V9200'} 1
# 100000263_1c4tc31a.jpg {'华为BBU5900'} 1
# 100000263_oa2k7k87.jpg {'中兴V9200'} 1
# 100000263_fmseqirg.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_yy61c7py.jpg {'爱立信BB6630'} 1
# 100000263_1gn5f031.jpg {'华为BBU5900'} 1
# 100000263_7o6ul8g0.jpg {'中兴V9200'} 1
# 100000263_3dmv34w8.jpg {'中兴V9200'} 1
# 100000263_steni838.jpg {'华为BBU3910', '华为BBU5900'} 3
# 100000263_35d4cbx2.jpg {'中兴V9200'} 1
# 100000263_61070r1q.jpg {'华为BBU5900'} 1
# 100000263_p0382pa6.jpg {'中兴V9200'} 1
# 100000263_70810bor.jpg {'中兴V9200'} 1
# 100000263_068r15s3.jpg {'华为BBU5900'} 1
# 100000263_u7hcox03.jpg {'爱立信BB6630'} 2
# 100000263_ljrgp087.jpg {'爱立信BB6630'} 1
# 100000263_t66rml47.jpg {'华为BBU5900'} 1
# 100000263_cytsl4dp.jpg {'中兴V9200'} 1
# 100000263_l44tek2v.jpg {'华为BBU5900'} 1
# 100000263_44s2v30h.jpg {'爱立信BB6630'} 1
# 100000263_bu351sax.jpg {'华为BBU5900'} 1
# 100000263_t6gdr1vb.jpg {'爱立信BB6630'} 1
# 100000263_vilc00k5.jpg {'爱立信BB6630'} 2
# 100000263_m03322ys.jpg {'华为BBU5900'} 1
# 100000263_evw45ads.jpg {'中兴V9200'} 1
# 100000263_a3nv14ou.jpg {'华为BBU5900'} 1
# 100000263_5o30wuew.jpg {'中兴V9200'} 1
# 100000263_mcrx2ago.jpg {'中兴V9200'} 1
# 100000263_8x02872w.jpg {'中兴V9200'} 1
# 100000263_75s75q1u.jpg {'爱立信BB6630'} 2
# 100000263_gv87yhsk.jpg {'中兴V9200'} 1
# 100000263_ota3e0ag.jpg {'华为BBU5900'} 1
# 100000263_0a1g3256.jpg {'华为BBU5900'} 1
# 100000263_038rl75t.jpg {'中兴V9200'} 1
# 100000263_1iyd2p83.jpg {'华为BBU3910'} 1
# 100000263_ja6eii5m.jpg {'爱立信BB6630'} 3
# 100000263_odvhdbsg.jpg {'中兴V9200'} 1
# 100000263_rx5047k1.jpg {'华为BBU3910'} 2
# 100000263_ic4r4oha.jpg {'中兴V9200'} 1
# 100000263_yk0oa0vk.jpg {'中兴V9200'} 1
# 100000263_h0vjog1s.jpg {'爱立信BB6630'} 5
# 100000263_11f4yxm2.jpg {'爱立信BB6630'} 1
# 100000263_yp15h0v0.jpg {'中兴V9200'} 1
# 100000263_8lp0v686.jpg {'中兴V9200'} 1
# 100000263_sqsi5f6x.jpg {'中兴V9200'} 1
# 100000263_s35213cm.jpg {'中兴B8300'} 1
# 100000263_47r63o33.jpg {'中兴V9200'} 1
# 100000263_600e1t38.jpg {'华为BBU5900'} 1
# 100000263_kfkb071d.jpg {'中兴V9200'} 1
# 100000263_hv421535.jpg {'中兴V9200'} 1
# 100000263_kkslqd8o.jpg {'华为BBU5900'} 1
# 100000263_c6310586.jpg {'中兴V9200'} 1
# 100000263_ld3316u8.jpg {'爱立信BB6630', '诺基亚 FSIH'} 3
# 100000263_18y86008.jpg {'中兴V9200'} 1
# 100000263_tqahf6qi.jpg {'华为BBU5900'} 1
# 100000263_x85s2e6t.jpg {'爱立信BB6630'} 1
# 100000263_206g1b1b.jpg {'华为BBU5900'} 1
# 100000263_1m4ht170.jpg {'华为BBU5900'} 1
# 100000263_0331u0yl.jpg {'爱立信BB6630'} 3
# 100000263_ys008rch.jpg {'中兴V9200'} 1
# 100000263_l7y0q7u8.jpg {'华为BBU5900'} 1
# 100000263_8c7k3mea.jpg {'华为BBU5900'} 1
# 100000263_67l4855b.jpg {'华为BBU5900'} 1
# 100000263_y8214o11.jpg {'中兴V9200'} 1
# 100000263_pav57n1d.jpg {'华为BBU5900'} 1
# 100000263_26d8y57i.jpg {'中兴V9200'} 1
# 100000263_6d1272yi.jpg {'中兴V9200'} 1
# 100000263_4e34if1j.jpg {'中兴V9200'} 1
# 100000263_l6i23640.jpg {'中兴V9200'} 1
# 100000263_n71vj1o3.jpg {'华为BBU5900'} 1
# 100000263_7v5qk3in.jpg {'爱立信BB6630'} 1
# 100000263_2o50s3sl.jpg {'中兴V9200'} 1
# 100000263_w1c7t2fm.jpg {'华为BBU5900'} 1
# 100000263_80453knf.jpg {'华为BBU5900'} 1
# 100000263_f0d8b87h.jpg {'华为BBU5900'} 1
# 100000263_xo5a3423.jpg {'爱立信BB6630'} 1
# 100000263_u3s5yr1t.jpg {'爱立信BB6630'} 2
# 100000263_8dcx6s47.jpg {'中兴B8300'} 1
# 100000263_060ec5l5.jpg {'中兴V9200'} 1
# 100000263_w785if06.jpg {'中兴V9200'} 1
# 100000263_va8a54n5.jpg {'爱立信BB6630'} 1
# 100000263_o25m08td.jpg {'华为BBU5900'} 1
# 100000263_0v44w0dp.jpg {'爱立信BB6630'} 1
# 100000263_gt3xk3m7.jpg {'华为BBU5900'} 1
# 100000263_kvt5d32n.jpg {'华为BBU3910'} 1
# 100000263_8335togb.jpg {'中兴V9200'} 1
# 100000263_2354r835.jpg {'中兴V9200'} 1
# 100000263_v80ll3ip.jpg {'华为BBU5900'} 1
# 100000263_rxle4o20.jpg {'华为BBU5900'} 1
# 100000263_mk56xp6x.jpg {'华为BBU5900'} 1
# 100000263_637j4p3w.jpg {'中兴V9200'} 1
# 100000263_ri8ewx3b.jpg {'中兴V9200'} 1
# 100000263_pmwwifto.jpg {'中兴V9200'} 1
# 100000263_i75315m4.jpg {'中兴V9200'} 1
# 100000263_hld7188h.jpg {'中兴V9200'} 1
# 100000263_ofsm181b.jpg {'中兴V9200'} 1
# 100000263_s065lq2q.jpg {'中兴V9200'} 1
# 100000263_ik28386e.jpg {'爱立信BB6630'} 2
# 100000263_3qbm76ms.jpg {'中兴V9200'} 1
# 100000263_ysh3it75.jpg {'中兴V9200'} 1
# 100000263_11sb4057.jpg {'华为BBU5900'} 1
# 100000263_3r21752i.jpg {'中兴V9200'} 1
# 100000263_1bkxw8ps.jpg {'华为BBU5900'} 1
# 100000263_5d1fwyw0.jpg {'华为BBU5900'} 1
# 100000263_u4212ds3.jpg {'华为BBU5900'} 1
# 100000263_44ut55v1.jpg {'华为BBU5900'} 1
# 100000263_7u3f3i8w.jpg {'中兴V9200'} 1
# 100000263_a22mp0w8.jpg {'中兴V9200'} 1
# 100000263_j4jbr06m.jpg {'诺基亚 Airscale'} 1
# 100000263_828157v3.jpg {'中兴V9200'} 1
# 100000263_t0plrrkc.jpg {'爱立信BB6630'} 1
# 100000263_0ong5lrx.jpg {'中兴V9200'} 1
# 100000263_w4w6g708.jpg {'华为BBU5900'} 1
# 100000263_8hhgy4c1.jpg {'中兴V9200'} 1
# 100000263_ak50330j.jpg {'中兴V9200'} 1
# 100000263_18dolqn6.jpg {'华为BBU5900'} 1
# 100000263_18i1k67o.jpg {'华为BBU5900'} 2
# 100000263_wb28n1j5.jpg {'中兴V9200'} 1
# 100000263_636y2as5.jpg {'华为BBU5900'} 1
# 100000263_v5b78tv7.jpg {'爱立信BB6630'} 3
# 100000263_24i54i68.jpg {'华为BBU5900'} 1
# 100000263_363hqxf2.jpg {'爱立信BB6630'} 2
# 100000263_778sc044.jpg {'中兴V9200'} 1
# 100000263_37ca046c.jpg {'爱立信BB6630'} 1
# 100000263_3l51tb30.jpg {'爱立信BB6630'} 4
# 100000263_dj6lcw00.jpg {'华为BBU5900'} 1
# 100000263_a7a3w5yi.jpg {'爱立信BB6630'} 2
# 100000263_wua60p01.jpg {'中兴V9200'} 1
# 100000263_82e06lpt.jpg {'爱立信BB6630'} 3
# 100000263_w6y26cwa.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_n02703fe.jpg {'中兴V9200'} 1
# 100000263_a5h1i2h1.jpg {'中兴V9200'} 1
# 100000263_ion44x37.jpg {'中兴V9200'} 1
# 100000263_q7562101.jpg {'中兴V9200'} 1
# 100000263_016lo8h2.jpg {'爱立信BB6630'} 1
# 100000263_q66k672i.jpg {'爱立信BB6630'} 3
# 100000263_s8tq67y3.jpg {'中兴V9200'} 1
# 100000263_768m8or1.jpg {'华为BBU5900'} 1
# 100000263_w0p2a2qo.jpg {'爱立信BB6630'} 1
# 100000263_uk6evpvc.jpg {'华为BBU5900'} 1
# 100000263_o20t3wlt.jpg {'华为BBU5900'} 1
# 100000263_551g226a.jpg {'爱立信BB6630'} 1
# 100000263_82oy68jc.jpg {'华为BBU5900'} 1
# 100000263_pq404257.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_om4qdnc2.jpg {'中兴V9200'} 1
# 100000263_ttvpnk47.jpg {'爱立信BB6630'} 1
# 100000263_r4vi375j.jpg {'中兴V9200'} 1
# 100000263_g5x64xdy.jpg {'爱立信BB6630'} 4
# 100000263_1d4n20dc.jpg {'中兴V9200'} 1
# 100000263_4f8ti0cc.jpg {'中兴V9200'} 1
# 100000263_4n2flp2m.jpg {'中兴V9200'} 1
# 100000263_g3v7dg56.jpg {'中兴V9200'} 1
# 100000263_1e73hu10.jpg {'华为BBU5900'} 1
# 100000263_h22q4j1e.jpg {'中兴B8300'} 1
# 100000263_33a4m35k.jpg {'中兴V9200'} 1
# 100000263_e71w544n.jpg {'华为BBU5900'} 1
# 100000263_58rfc1w3.jpg {'华为BBU5900'} 1
# 100000263_h62373un.jpg {'中兴V9200'} 1
# 100000263_m7031164.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_jm3m404n.jpg {'华为BBU5900'} 1
# 100000263_886r5o37.jpg {'中兴V9200'} 1
# 100000263_x2c3ljsx.jpg {'华为BBU5900'} 1
# 100000263_h27i1kuv.jpg {'爱立信BB6630'} 2
# 100000263_2a5o3d3b.jpg {'华为BBU5900'} 1
# 100000263_r01100ec.jpg {'华为BBU5900'} 1
# 100000263_42wblo4k.jpg {'爱立信BB6630'} 1
# 100000263_wtrb85ud.jpg {'中兴V9200'} 1
# 100000263_750i7fr1.jpg {'中兴V9200'} 1
# 100000263_kxed8idt.jpg {'华为BBU3910'} 1
# 100000263_dn263w12.jpg {'中兴V9200'} 1
# 100000263_82f3lya4.jpg {'中兴V9200'} 1
# 100000263_q8555wgb.jpg {'中兴V9200'} 1
# 100000263_t116j8a3.jpg {'中兴V9200'} 1
# 100000263_0b0ts745.jpg {'华为BBU5900'} 1
# 100000263_8p6y4238.jpg {'爱立信BB6630'} 1
# 100000263_17008f8h.jpg {'华为BBU5900'} 1
# 100000263_7c20l343.jpg {'中兴V9200'} 1
# 100000263_1q48n1ly.jpg {'华为BBU5900'} 1
# 100000263_ja5k2e47.jpg {'华为BBU5900'} 1
# 100000263_v2plf310.jpg {'中兴V9200'} 1
# 100000263_5l7cmgn4.jpg {'中兴V9200'} 1
# 100000263_72pd6mw3.jpg {'中兴V9200'} 1
# 100000263_pl6bi6cx.jpg {'爱立信BB6630'} 3
# 100000263_512o06ns.jpg {'中兴V9200'} 1
# 100000263_c5r087yv.jpg {'中兴V9200'} 1
# 100000263_at33w3x5.jpg {'爱立信BB6630'} 1
# 100000263_rj1516p7.jpg {'中兴V9200'} 1
# 100000263_y5m11w3t.jpg {'华为BBU5900'} 1
# 100000263_lv1aaplx.jpg {'华为BBU5900'} 1
# 100000263_u415ca60.jpg {'中兴V9200'} 1
# 100000263_3v42m742.jpg {'华为BBU5900'} 1
# 100000263_la3xso51.jpg {'中兴V9200'} 1
# 100000263_8p842236.jpg {'中兴V9200'} 1
# 100000263_55n1doi7.jpg {'中兴V9200'} 1
# 100000263_ue62j38x.jpg {'中兴V9200'} 1
# 100000263_cu88gfrt.jpg {'华为BBU5900'} 1
# 100000263_y12v8022.jpg {'华为BBU5900'} 1
# 100000263_42g568nb.jpg {'爱立信BB6630'} 1
# 100000263_0385p6v0.jpg {'爱立信BB6630'} 1
# 100000263_y8e2ulgf.jpg {'华为BBU5900'} 1
# 100000263_gu3sluxo.jpg {'爱立信BB6630'} 1
# 100000263_ja2tsc24.jpg {'爱立信BB6630'} 1
# 100000263_7fk34q4r.jpg {'爱立信BB6630'} 1
# 100000263_s34ca4s0.jpg {'爱立信BB6630'} 2
# 100000263_6fq0fn7s.jpg {'中兴V9200'} 1
# 100000263_6s17r67j.jpg {'中兴V9200'} 1
# 100000263_67c34j5b.jpg {'华为BBU5900'} 1
# 100000263_wemk174h.jpg {'华为BBU5900'} 1
# 100000263_go01nx07.jpg {'华为BBU5900'} 1
# 100000263_taja5f1g.jpg {'华为BBU5900'} 1
# 100000263_s4h8s21h.jpg {'中兴V9200'} 1
# 100000263_8k33h22e.jpg {'华为BBU5900'} 1
# 100000263_mf5m45di.jpg {'爱立信BB6630'} 3
# 100000263_n1234874.jpg {'爱立信BB6630'} 1
# 100000263_iw67bb5v.jpg {'中兴V9200'} 1
# 100000263_v33r35it.jpg {'华为BBU5900'} 1
# 100000263_nj7604hy.jpg {'中兴V9200'} 1
# 100000263_67u17d88.jpg {'中兴V9200'} 1
# 100000263_206v70po.jpg {'爱立信BB6630'} 1
# 100000263_d5gelldh.jpg {'华为BBU5900'} 1
# 100000263_s3oh0a87.jpg {'爱立信BB6630'} 2
# 100000263_bdt04vbj.jpg {'爱立信BB6630'} 1
# 100000263_s2u3s41j.jpg {'爱立信BB6648'} 1
# 100000263_452wvdl1.jpg {'爱立信BB6630'} 2
# 100000263_vdhu3n2d.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_fff5d7rx.jpg {'中兴V9200'} 1
# 100000263_60c85vbv.jpg {'中兴B8300', '华为BBU5900'} 2
# 100000263_rr2101j6.jpg {'中兴V9200'} 1
# 100000263_e21f2635.jpg {'华为BBU5900'} 1
# 100000263_6m66s72r.jpg {'中兴V9200'} 1
# 100000263_ximmv8j5.jpg {'爱立信BB6630'} 3
# 100000263_c6yn8w2d.jpg {'爱立信BB6630'} 1
# 100000263_13jxc7hr.jpg {'华为BBU5900'} 1
# 100000263_dh188ssh.jpg {'华为BBU5900'} 1
# 100000263_03q8120u.jpg {'中兴V9200'} 1
# 100000263_k5028508.jpg {'华为BBU5900'} 1
# 100000263_638nql4m.jpg {'爱立信BB6630'} 1
# 100000263_71ci562g.jpg {'中兴V9200'} 1
# 100000263_0fpr633y.jpg {'华为BBU5900'} 1
# 100000263_13fdwvf5.jpg {'中兴V9200'} 1
# 100000263_73be0b8c.jpg {'中兴V9200'} 1
# 100000263_111vt888.jpg {'爱立信BB6630'} 1
# 100000263_vvjbn1fl.jpg {'中兴V9200'} 1
# 100000263_agn1tanj.jpg {'中兴V9200'} 1
# 100000263_5206q2b5.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_3x86q6j3.jpg {'中兴B8300'} 1
# 100000263_62oejn4i.jpg {'爱立信BB6630'} 1
# 100000263_1n885d40.jpg {'中兴V9200'} 1
# 100000263_862c522r.jpg {'爱立信BB6630'} 1
# 100000263_ii7o12ry.jpg {'爱立信BB6630'} 1
# 100000263_503y36g6.jpg {'华为BBU5900'} 1
# 100000263_3348y3r1.jpg {'中兴V9200'} 1
# 100000263_qnh03roh.jpg {'爱立信BB6630'} 1
# 100000263_ej22f3fm.jpg {'中兴V9200'} 1
# 100000263_t603xg8y.jpg {'华为BBU3900'} 1
# 100000263_6wt3117i.jpg {'中兴V9200'} 1
# 100000263_6r3614nh.jpg {'中兴V9200'} 1
# 100000263_q5mqhwwo.jpg {'中兴B8300'} 1
# 100000263_11yx1xlr.jpg {'中兴V9200', '中兴B8300'} 2
# 100000263_y1dgn281.jpg {'华为BBU5900'} 1
# 100000263_s0c18dw2.jpg {'爱立信BB6630'} 1
# 100000263_wm16t2s1.jpg {'爱立信BB6630'} 1
# 100000263_2357ys5m.jpg {'中兴V9200'} 1
# 100000263_qu88f5v0.jpg {'爱立信BB6630'} 1
# 100000263_66143isj.jpg {'中兴V9200'} 1
# 100000263_134n2214.jpg {'中兴V9200'} 1
# 100000263_550s4u5h.jpg {'华为BBU5900'} 1
# 100000263_85yi5507.jpg {'华为BBU5900'} 1
# 100000263_e8g0k7of.jpg {'中兴V9200'} 1
# 100000263_b1iv8v15.jpg {'爱立信BB6630'} 2
# 100000263_6d0n7tne.jpg {'华为BBU5900'} 1
# 100000263_351om4hb.jpg {'中兴V9200'} 1
# 100000263_431vvx54.jpg {'爱立信BB6630'} 1
# 100000263_j7brmrl7.jpg {'中兴V9200'} 1
# 100000263_a6r7dbne.jpg {'华为BBU5900'} 1
# 100000263_a66a1i0b.jpg {'中兴V9200'} 1
# 100000263_857us3d7.jpg {'爱立信BB6630'} 1
# 100000263_g58cio60.jpg {'中兴V9200'} 1
# 100000263_6q0d730d.jpg {'中兴V9200'} 1
# 100000263_y1401kg5.jpg {'中兴V9200'} 1
# 100000263_m6ws836u.jpg {'华为BBU5900'} 1
# 100000263_01053b05.jpg {'中兴V9200'} 1
# 100000263_s5ame104.jpg {'中兴V9200'} 1
# 100000263_xv11uvdd.jpg {'爱立信BB6630'} 6
# 100000263_vja6g71n.jpg {'华为BBU3910'} 1
# 100000263_bf058e0i.jpg {'爱立信BB6648'} 1
# 100000263_ldp3yqre.jpg {'爱立信BB6630'} 1
# 100000263_0duamdh1.jpg {'华为BBU5900'} 1
# 100000263_lbni0d1v.jpg {'中兴V9200'} 1
# 100000263_10c1u5df.jpg {'华为BBU3910'} 1
# 100000263_6vsxq645.jpg {'中兴V9200'} 1
# 100000263_081r32e3.jpg {'华为BBU5900'} 1
# 100000263_24yda6rs.jpg {'中兴V9200'} 1
# 100000263_11080424.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_e4jujmse.jpg {'华为BBU5900'} 1
# 100000263_7gct38g8.jpg {'爱立信BB6630'} 1
# 100000263_cfa7t63p.jpg {'爱立信BB6630'} 1
# 100000263_5n61hh11.jpg {'中兴V9200'} 1
# 100000263_kn232646.jpg {'中兴V9200'} 1
# 100000263_bonhjl33.jpg {'华为BBU5900'} 1
# 100000263_574q63n1.jpg {'爱立信BB6630'} 1
# 100000263_73t833gn.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_4lo34nd7.jpg {'中兴V9200'} 1
# 100000263_n44d30vw.jpg {'华为BBU5900'} 1
# 100000263_mkl625dj.jpg {'爱立信BB6630'} 1
# 100000263_7ih0f278.jpg {'诺基亚 Airscale', '华为BBU5900'} 2
# 100000263_ih05u52t.jpg {'中兴V9200'} 1
# 100000263_1nj7287q.jpg {'中兴V9200'} 1
# 100000263_xh7c3q7u.jpg {'华为BBU5900'} 2
# 100000263_g7klr0c0.jpg {'爱立信BB6630'} 4
# 100000263_5s6r57sn.jpg {'爱立信BB6630'} 1
# 100000263_ih8gn6kw.jpg {'华为BBU5900'} 1
# 100000263_156iw3n4.jpg {'爱立信BB6630'} 1
# 100000263_744s82i3.jpg {'爱立信BB6630'} 1
# 100000263_c3mig03v.jpg {'中兴V9200'} 1
# 100000263_j3v63000.jpg {'爱立信BB6630'} 1
# 100000263_wg001q81.jpg {'华为BBU5900'} 1
# 100000263_6rydb2q1.jpg {'爱立信BB6648'} 1
# 100000263_er5u2moh.jpg {'中兴V9200'} 1
# 100000263_20pn5t2y.jpg {'爱立信BB6648'} 1
# 100000263_7qr57b21.jpg {'华为BBU5900'} 1
# 100000263_278xx771.jpg {'华为BBU3900'} 1
# 100000263_1uqlg61j.jpg {'中兴V9200'} 1
# 100000263_33soh5s3.jpg {'中兴V9200'} 1
# 100000263_a881qywy.jpg {'爱立信BB6630'} 3
# 100000263_u806j538.jpg {'华为BBU5900'} 1
# 100000263_08sfwpwh.jpg {'中兴V9200'} 1
# 100000263_ecq84cdu.jpg {'华为BBU5900'} 1
# 100000263_m78gd601.jpg {'华为BBU5900'} 1
# 100000263_w6u2j27s.jpg {'华为BBU5900'} 2
# 100000263_ns5vwvqe.jpg {'中兴V9200'} 1
# 100000263_w3p646r3.jpg {'爱立信BB6630'} 2
# 100000263_j5l47177.jpg {'爱立信BB6630'} 2
# 100000263_5wo5b68n.jpg {'爱立信BB6630'} 1
# 100000263_s1754q4u.jpg {'爱立信BB6630'} 1
# 100000263_krx4flyq.jpg {'中兴V9200'} 1
# 100000263_11618b8j.jpg {'华为BBU5900'} 1
# 100000263_knt3cg30.jpg {'爱立信BB6630'} 1
# 100000263_32064g33.jpg {'中兴V9200'} 1
# 100000263_n5ing3o2.jpg {'中兴B8300'} 1
# 100000263_3bad2jkg.jpg {'中兴V9200'} 1
# 100000263_jd231hdm.jpg {'中兴V9200'} 1
# 100000263_n76k320e.jpg {'中兴V9200'} 1
# 100000263_0q4dmon2.jpg {'中兴V9200'} 1
# 100000263_y881h88u.jpg {'中兴V9200'} 1
# 100000263_y0p1b462.jpg {'中兴V9200'} 1
# 100000263_173v0gd7.jpg {'中兴V9200'} 1
# 100000263_08vc447p.jpg {'爱立信BB6630'} 3
# 100000263_1aa322r1.jpg {'爱立信BB6630'} 2
# 100000263_hr0c0376.jpg {'中兴V9200'} 1
# 100000263_b1pse84r.jpg {'中兴V9200'} 1
# 100000263_na5041jo.jpg {'中兴V9200'} 2
# 100000263_b28gopd7.jpg {'华为BBU5900'} 1
# 100000263_yk53fb2u.jpg {'中兴V9200'} 1
# 100000263_71id7pxp.jpg {'爱立信BB6648'} 1
# 100000263_1ep1202o.jpg {'爱立信BB6630'} 1
# 100000263_cd31q8fn.jpg {'华为BBU5900'} 1
# 100000263_bvb5l6p7.jpg {'华为BBU5900'} 1
# 100000263_e4oo3413.jpg {'中兴V9200'} 1
# 100000263_o1a4l845.jpg {'中兴V9200'} 1
# 100000263_37617ql3.jpg {'中兴V9200'} 1
# 100000263_on1egl14.jpg {'中兴V9200'} 2
# 100000263_1rtp18lb.jpg {'中兴V9200'} 2
# 100000263_46dx04ko.jpg {'华为BBU5900'} 1
# 100000263_l3c278v8.jpg {'华为BBU5900'} 1
# 100000263_bg5j2i8w.jpg {'中兴V9200'} 1
# 100000263_7nrf3676.jpg {'爱立信BB6630'} 1
# 100000263_h2q52880.jpg {'爱立信BB6630'} 1
# 100000263_w2ac1175.jpg {'中兴V9200'} 1
# 100000263_c6x51hwb.jpg {'华为BBU5900'} 1
# 100000263_5at6qu6h.jpg {'华为BBU5900'} 1
# 100000263_0wygvlq5.jpg {'华为BBU5900'} 1
# 100000263_55o6gisw.jpg {'中兴V9200'} 1
# 100000263_48ut16j6.jpg {'华为BBU5900'} 1
# 100000263_dnmy3y11.jpg {'爱立信BB6630'} 2
# 100000263_xwywa5aa.jpg {'华为BBU5900'} 1
# 100000263_3m4j5464.jpg {'中兴V9200'} 1
# 100000263_4l10u40n.jpg {'华为BBU5900'} 1
# 100000263_b4qac360.jpg {'华为BBU5900'} 1
# 100000263_c84343g4.jpg {'华为BBU5900'} 1
# 100000263_d14tsq27.jpg {'爱立信BB6630'} 3
# 100000263_0h6q4b20.jpg {'中兴V9200'} 1
# 100000263_urgq0iy0.jpg {'华为BBU5900'} 1
# 100000263_iuq5odx2.jpg {'华为BBU5900'} 2
# 100000263_181s6546.jpg {'华为BBU5900'} 2
# 100000263_j3grsim5.jpg {'中兴V9200'} 1
# 100000263_g22cey40.jpg {'中兴V9200'} 1
# 100000263_djno0h0k.jpg {'中兴V9200'} 1
# 100000263_frb3txe1.jpg {'华为BBU5900'} 1
# 100000263_sa1rmiha.jpg {'爱立信BB6630'} 3
# 100000263_8nl26vdt.jpg {'中兴V9200'} 1
# 100000263_053806mv.jpg {'中兴V9200'} 1
# 100000263_qn4123l2.jpg {'中兴V9200'} 1
# 100000263_w85871nc.jpg {'中兴V9200'} 1
# 100000263_bh273y83.jpg {'爱立信BB6630'} 1
# 100000263_e2ovkp5u.jpg {'爱立信BB6630'} 1
# 100000263_5yg5bp0f.jpg {'爱立信BB6630'} 2
# 100000263_ko3fkv02.jpg {'爱立信BB6630'} 2
# 100000263_s42c861d.jpg {'华为BBU5900'} 1
# 100000263_h5kq2516.jpg {'华为BBU5900'} 1
# 100000263_y5j51m01.jpg {'中兴V9200'} 1
# 100000263_86886571.jpg {'爱立信BB6630'} 1
# 100000263_6be6a6er.jpg {'爱立信BB6630'} 3
# 100000263_aj10ocy6.jpg {'爱立信BB6630'} 1
# 100000263_fdlgd72n.jpg {'华为BBU5900'} 1
# 100000263_cv285q61.jpg {'中兴V9200'} 1
# 100000263_fs717oxc.jpg {'华为BBU3910'} 1
# 100000263_4677ibv8.jpg {'爱立信BB6648'} 2
# 100000263_eyn8b4xx.jpg {'中兴V9200'} 1
# 100000263_375fbgyk.jpg {'华为BBU5900'} 1
# 100000263_0k65hr02.jpg {'华为BBU5900'} 1
# 100000263_e8pg2k58.jpg {'中兴V9200'} 1
# 100000263_0p86bgrl.jpg {'诺基亚 FSIH'} 1
# 100000263_h8q0d0sg.jpg {'中兴V9200'} 1
# 100000263_n4e32428.jpg {'中兴V9200'} 1
# 100000263_2n7frtyl.jpg {'华为BBU5900'} 2
# 100000263_nk7606bl.jpg {'爱立信BB6630'} 1
# 100000263_5j5pqy06.jpg {'中兴V9200'} 1
# 100000263_6y0lj67s.jpg {'中兴V9200'} 1
# 100000263_c4druc5d.jpg {'中兴V9200'} 1
# 100000263_l38y24t0.jpg {'中兴V9200'} 1
# 100000263_k41ac371.jpg {'华为BBU5900'} 1
# 100000263_2s4d506w.jpg {'爱立信BB6630'} 2
# 100000263_86tq04mp.jpg {'爱立信BB6630'} 1
# 100000263_s5uxfhqd.jpg {'爱立信BB6630'} 1
# 100000263_gd11irut.jpg {'华为BBU5900'} 1
# 100000263_5w37p317.jpg {'中兴V9200'} 1
# 100000263_8i16lxyh.jpg {'爱立信BB6630'} 2
# 100000263_2t42hsk2.jpg {'华为BBU5900'} 1
# 100000263_215p58o6.jpg {'爱立信BB6630'} 2
# 100000263_5m0h137c.jpg {'华为BBU5900'} 1
# 100000263_s284k2k8.jpg {'爱立信BB6630'} 1
# 100000263_y7aa0y40.jpg {'爱立信BB6630'} 1
# 100000263_cbgmxd4v.jpg {'爱立信BB6630'} 1
# 100000263_5pbc4608.jpg {'中兴V9200'} 1
# 100000263_q8e6475n.jpg {'中兴V9200'} 1
# 100000263_4n2730y5.jpg {'爱立信BB6630'} 1
# 100000263_ox126765.jpg {'爱立信BB6630'} 2
# 100000263_140x3186.jpg {'爱立信BB6630'} 1
# 100000263_4eyd0iu2.jpg {'中兴V9200'} 1
# 100000263_t2sv821o.jpg {'中兴V9200'} 1
# 100000263_vx6ek4jx.jpg {'华为BBU5900'} 1
# 100000263_krjp1bgk.jpg {'爱立信BB6630'} 2
# 100000263_456n7551.jpg {'中兴V9200'} 1
# 100000263_q4i048u3.jpg {'中兴V9200'} 1
# 100000263_u0rw715t.jpg {'华为BBU5900'} 1
# 100000263_85o1grg8.jpg {'中兴V9200'} 1
# 100000263_405gqup7.jpg {'爱立信BB6630'} 1
# 100000263_a43dm5mg.jpg {'爱立信BB6630'} 1
# 100000263_lka7750j.jpg {'华为BBU5900'} 1
# 100000263_dqd1g7p8.jpg {'爱立信BB6630'} 1
# 100000263_w6riwn77.jpg {'华为BBU5900'} 1
# 100000263_0du62382.jpg {'爱立信BB6630'} 2
# 100000263_63q76ds2.jpg {'华为BBU5900'} 1
# 100000263_43gh6ol4.jpg {'华为BBU5900'} 1
# 100000263_04inv7wd.jpg {'中兴V9200'} 1
# 100000263_uh888us6.jpg {'爱立信BB6630'} 1
# 100000263_517247fr.jpg {'华为BBU5900'} 1
# 100000263_1f55qv76.jpg {'中兴V9200'} 1
# 100000263_b5mom7wo.jpg {'中兴V9200'} 1
# 100000263_3fue5480.jpg {'华为BBU5900'} 1
# 100000263_6ocvd36v.jpg {'华为BBU5900'} 1
# 100000263_2u052rb3.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_tw145irv.jpg {'中兴V9200'} 1
# 100000263_oam28vfj.jpg {'中兴V9200'} 1
# 100000263_6gudqnm4.jpg {'华为BBU5900'} 1
# 100000263_3ee6gkg1.jpg {'中兴V9200'} 1
# 100000263_0u15sv72.jpg {'中兴V9200'} 1
# 100000263_41g3h052.jpg {'华为BBU5900'} 1
# 100000263_65srbnh1.jpg {'爱立信BB6630'} 3
# 100000263_k8ej541e.jpg {'中兴V9200'} 1
# 100000263_05713u72.jpg {'爱立信BB6630'} 1
# 100000263_o0sg4qw2.jpg {'爱立信BB6630'} 1
# 100000263_8s565t20.jpg {'中兴V9200'} 1
# 100000263_v35xvq8q.jpg {'华为BBU5900'} 1
# 100000263_f4xcw4sl.jpg {'华为BBU5900'} 1
# 100000263_84f6g865.jpg {'中兴V9200'} 1
# 100000263_quat8inp.jpg {'华为BBU5900'} 1
# 100000263_53e5t407.jpg {'爱立信BB6630'} 1
# 100000263_1m52p4ch.jpg {'中兴V9200'} 1
# 100000263_lx4q5gbo.jpg {'中兴V9200'} 1
# 100000263_1mhm8281.jpg {'华为BBU5900'} 1
# 100000263_50wv00f0.jpg {'中兴V9200'} 1
# 100000263_4238v5e2.jpg {'中兴V9200'} 1
# 100000263_1i3t75q2.jpg {'中兴V9200'} 1
# 100000263_8a7pyi8d.jpg {'爱立信BB6630'} 3
# 100000263_677a7g4x.jpg {'中兴V9200'} 1
# 100000263_0206qh47.jpg {'中兴V9200'} 1
# 100000263_aes0470q.jpg {'华为BBU5900'} 1
# 100000263_b5b31423.jpg {'华为BBU5900'} 1
# 100000263_uu51j22m.jpg {'爱立信BB6630'} 1
# 100000263_23i4e733.jpg {'中兴V9200'} 1
# 100000263_77u57bqt.jpg {'爱立信BB6630'} 1
# 100000263_706wxrwl.jpg {'华为BBU5900'} 1
# 100000263_a748uo0s.jpg {'中兴V9200'} 1
# 100000263_iya246gt.jpg {'爱立信BB6630'} 1
# 100000263_28m7rl4o.jpg {'爱立信BB6630'} 1
# 100000263_uuj78j1h.jpg {'中兴V9200'} 1
# 100000263_b61f204k.jpg {'华为BBU5900'} 1
# 100000263_l76hn52u.jpg {'爱立信BB6630'} 3
# 100000263_3l1dbtjf.jpg {'爱立信BB6630'} 3
# 100000263_65wvmuwf.jpg {'爱立信BB6630'} 1
# 100000263_1462g2l0.jpg {'中兴V9200'} 1
# 100000263_j02fgp3t.jpg {'华为BBU5900'} 1
# 100000263_7x0e801i.jpg {'中兴V9200'} 1
# 100000263_tri41l20.jpg {'爱立信BB6630'} 1
# 100000263_w168im51.jpg {'华为BBU5900'} 1
# 100000263_8l43r611.jpg {'中兴V9200'} 1
# 100000263_ba3s26ph.jpg {'中兴V9200'} 1
# 100000263_70uq8cad.jpg {'爱立信BB6630'} 2
# 100000263_rd47bv4b.jpg {'华为BBU5900'} 1
# 100000263_s21q5f37.jpg {'中兴V9200'} 1
# 100000263_2r3571jd.jpg {'中兴V9200'} 1
# 100000263_37xya08m.jpg {'爱立信BB6630'} 1
# 100000263_p86jb023.jpg {'爱立信BB6630'} 1
# 100000263_2b2h3my0.jpg {'华为BBU5900'} 1
# 100000263_4oclc3j0.jpg {'华为BBU3910', '爱立信BB6630'} 2
# 100000263_s26jvi45.jpg {'华为BBU5900'} 1
# 100000263_bhfxxg70.jpg {'中兴V9200'} 1
# 100000263_k312fp46.jpg {'爱立信BB6630'} 1
# 100000263_8e00gs8x.jpg {'华为BBU3910'} 1
# 100000263_6200p1fl.jpg {'爱立信BB6630'} 2
# 100000263_f87qa1yw.jpg {'华为BBU5900'} 1
# 100000263_6nn274sr.jpg {'华为BBU5900'} 1
# 100000263_8lnw0uh5.jpg {'华为BBU5900'} 1
# 100000263_fjx1w62i.jpg {'爱立信BB6630'} 1
# 100000263_2jh28r36.jpg {'中兴V9200'} 1
# 100000263_ln5y5jl8.jpg {'华为BBU5900'} 1
# 100000263_x46ny7t1.jpg {'华为BBU5900'} 1
# 100000263_ik336750.jpg {'中兴V9200'} 1
# 100000263_82yqf201.jpg {'中兴B8300'} 1
# 100000263_5pl5j4bf.jpg {'中兴V9200'} 1
# 100000263_ep86eyfc.jpg {'中兴V9200'} 1
# 100000263_5ick3sah.jpg {'爱立信BB6630'} 2
# 100000263_vkpe8f43.jpg {'爱立信BB6630'} 1
# 100000263_yvn1241h.jpg {'爱立信BB6630'} 1
# 100000263_kolea1y6.jpg {'爱立信BB6630'} 1
# 100000263_wa10g88x.jpg {'华为BBU5900'} 1
# 100000263_y2kyk720.jpg {'中兴V9200'} 1
# 100000263_fku17ly0.jpg {'中兴V9200'} 2
# 100000263_ac5jh823.jpg {'中兴V9200'} 1
# 100000263_87i0j05b.jpg {'华为BBU5900'} 1
# 100000263_yfmf02n7.jpg {'诺基亚 Airscale'} 1
# 100000263_jefo181i.jpg {'华为BBU5900'} 1
# 100000263_c23u7a50.jpg {'爱立信BB6630'} 1
# 100000263_0ki6dtu5.jpg {'爱立信BB6648'} 1
# 100000263_ycuu40u8.jpg {'中兴V9200'} 1
# 100000263_513ali0x.jpg {'华为BBU5900'} 1
# 100000263_37ej0782.jpg {'爱立信BB6630'} 4
# 100000263_lgq8nda6.jpg {'爱立信BB6630'} 4
# 100000263_wl5e8qyy.jpg {'华为BBU5900'} 1
# 100000263_44m710tw.jpg {'华为BBU5900'} 1
# 100000263_i0515470.jpg {'中兴V9200'} 1
# 100000263_8ni34ww8.jpg {'中兴V9200'} 1
# 100000263_777ie1mp.jpg {'华为BBU5900'} 1
# 100000263_07f2fp5s.jpg {'华为BBU3910'} 1
# 100000263_15p2vvi6.jpg {'华为BBU5900'} 1
# 100000263_ngj652gt.jpg {'华为BBU5900'} 1
# 100000263_h540bd83.jpg {'爱立信BB6630'} 3
# 100000263_v800nhgy.jpg {'中兴V9200'} 1
# 100000263_35dli344.jpg {'爱立信BB6630'} 1
# 100000263_r78205ob.jpg {'中兴V9200'} 1
# 100000263_12o1kmg2.jpg {'中兴V9200'} 1
# 100000263_48037573.jpg {'华为BBU5900'} 1
# 100000263_7411ckr4.jpg {'华为BBU5900'} 1
# 100000263_0m2r1ps3.jpg {'中兴V9200'} 1
# 100000263_t4qw2588.jpg {'中兴V9200'} 1
# 100000263_hrmaal23.jpg {'中兴V9200'} 1
# 100000263_i8k31btc.jpg {'中兴V9200'} 1
# 100000263_j5cdv237.jpg {'华为BBU5900'} 1
# 100000263_m55tftrj.jpg {'华为BBU5900'} 1
# 100000263_0wdsh3ba.jpg {'华为BBU5900'} 1
# 100000263_8g5aai81.jpg {'中兴V9200'} 2
# 100000263_4v68620q.jpg {'中兴V9200'} 1
# 100000263_e25ub1ga.jpg {'爱立信BB6630'} 1
# 100000263_3gcj50ea.jpg {'中兴V9200'} 1
# 100000263_7xg7o51e.jpg {'华为BBU5900'} 1
# 100000263_gf073uvy.jpg {'爱立信BB6630'} 2
# 100000263_61825b38.jpg {'中兴V9200'} 1
# 100000263_x57mf3pf.jpg {'爱立信BB6630'} 2
# 100000263_j5i763q5.jpg {'中兴V9200'} 1
# 100000263_gl6r27pm.jpg {'爱立信BB6630'} 1
# 100000263_m8k6h017.jpg {'华为BBU5900'} 1
# 100000263_6st672yf.jpg {'华为BBU5900'} 1
# 100000263_o6s700lh.jpg {'爱立信BB6630'} 2
# 100000263_l33re0o1.jpg {'华为BBU5900'} 1
# 100000263_45p21kf5.jpg {'中兴V9200'} 1
# 100000263_8w4d143n.jpg {'中兴V9200'} 1
# 100000263_hi317sq4.jpg {'华为BBU5900'} 1
# 100000263_q635frif.jpg {'爱立信BB6630'} 1
# 100000263_gi6hkt83.jpg {'中兴V9200'} 1
# 100000263_60733168.jpg {'爱立信BB6630'} 1
# 100000263_p01bs768.jpg {'爱立信BB6630'} 1
# 100000263_d816m5m7.jpg {'华为BBU5900'} 1
# 100000263_f7xc06at.jpg {'中兴V9200'} 1
# 100000263_371l4d15.jpg {'爱立信BB6630'} 1
# 100000263_s030ce2c.jpg {'中兴V9200'} 1
# 100000263_6muglrq5.jpg {'爱立信BB6630'} 2
# 100000263_do4p6tb1.jpg {'中兴V9200'} 1
# 100000263_6fk5bhy7.jpg {'爱立信BB6630'} 1
# 100000263_703sb20a.jpg {'爱立信BB6648'} 2
# 100000263_y480i20x.jpg {'中兴V9200'} 1
# 100000263_1y8hu3u6.jpg {'爱立信BB6630'} 1
# 100000263_t5s132q1.jpg {'爱立信BB6630'} 1
# 100000263_u16us21i.jpg {'华为BBU5900'} 1
# 100000263_242a014r.jpg {'中兴V9200'} 1
# 100000263_y27ne22g.jpg {'华为BBU5900'} 1
# 100000263_2fmv68ot.jpg {'中兴V9200'} 1
# 100000263_32yp6dk4.jpg {'爱立信BB6630'} 3
# 100000263_x64wm1x8.jpg {'中兴V9200'} 1
# 100000263_j122tx57.jpg {'中兴V9200'} 1
# 100000263_1tg64kx3.jpg {'华为BBU5900'} 1
# 100000263_6w651pgy.jpg {'华为BBU5900'} 1
# 100000263_6d6yvw27.jpg {'中兴V9200'} 1
# 100000263_7c75f1s3.jpg {'中兴V9200'} 1
# 100000263_8p6mq0s2.jpg {'华为BBU5900'} 2
# 100000263_n14f8k40.jpg {'中兴V9200'} 2
# 100000263_u3kk81ks.jpg {'华为BBU5900'} 1
# 100000263_k0qshp2b.jpg {'爱立信BB6630'} 1
# 100000263_6r1d808f.jpg {'中兴V9200'} 1
# 100000263_a1366huu.jpg {'华为BBU5900'} 1
# 100000263_y6ivpmkh.jpg {'华为BBU5900'} 1
# 100000263_4kl53782.jpg {'华为BBU5900'} 1
# 100000263_c26qxw71.jpg {'爱立信BB6630'} 2
# 100000263_471b0jto.jpg {'爱立信BB6630'} 1
# 100000263_w8r708nb.jpg {'中兴V9200'} 1
# 100000263_wh842u61.jpg {'中兴V9200'} 1
# 100000263_m7s2gti3.jpg {'爱立信BB6648'} 2
# 100000263_sdph2ckv.jpg {'爱立信BB6630'} 1
# 100000263_m86kji75.jpg {'中兴V9200'} 2
# 100000263_whg1xms8.jpg {'华为BBU5900'} 1
# 100000263_62qwm4d4.jpg {'中兴V9200'} 1
# 100000263_6yl3s0pq.jpg {'中兴V9200'} 1
# 100000263_f5oqb546.jpg {'华为BBU5900'} 1
# 100000263_5v3e04n5.jpg {'中兴V9200'} 1
# 100000263_qr674d62.jpg {'中兴V9200'} 1
# 100000263_05lkd751.jpg {'华为BBU5900'} 1
# 100000263_61o3w5t4.jpg {'爱立信BB6630'} 6
# 100000263_7b3fq2b8.jpg {'中兴V9200'} 1
# 100000263_p1bfml1n.jpg {'爱立信BB6630'} 2
# 100000263_v5n5ay5m.jpg {'华为BBU5900'} 1
# 100000263_64q1gind.jpg {'爱立信BB6630'} 2
# 100000263_3a81ys7j.jpg {'爱立信BB6630'} 1
# 100000263_pqlh708u.jpg {'中兴V9200'} 1
# 100000263_6371612m.jpg {'中兴V9200'} 1
# 100000263_a8uwv5jj.jpg {'中兴V9200'} 1
# 100000263_44842x1m.jpg {'中兴V9200'} 1
# 100000263_4r7isq51.jpg {'爱立信BB6630'} 1
# 100000263_36q4rh50.jpg {'中兴V9200'} 1
# 100000263_7x55b64g.jpg {'中兴V9200'} 1
# 100000263_v2x70d50.jpg {'华为BBU5900'} 1
# 100000263_i3452b3i.jpg {'爱立信BB6648'} 1
# 100000263_qv73mk8t.jpg {'华为BBU5900'} 1
# 100000263_84b52f3g.jpg {'中兴V9200'} 1
# 100000263_d8ni785k.jpg {'中兴V9200'} 1
# 100000263_jskp511k.jpg {'华为BBU5900'} 1
# 100000263_t64yl501.jpg {'爱立信BB6648'} 2
# 100000263_65fsmwjd.jpg {'华为BBU5900'} 1
# 100000263_2x1iv810.jpg {'爱立信BB6630'} 2
# 100000263_oo2c7k35.jpg {'爱立信BB6630'} 2
# 100000263_057356bq.jpg {'中兴V9200'} 1
# 100000263_x76ek35l.jpg {'华为BBU5900'} 1
# 100000263_le3i6uc3.jpg {'中兴V9200'} 1
# 100000263_lmay13i6.jpg {'华为BBU5900'} 1
# 100000263_bj4a46ve.jpg {'中兴V9200'} 1
# 100000263_ugfq321u.jpg {'爱立信BB6630'} 1
# 100000263_eg7d67kr.jpg {'中兴V9200'} 1
# 100000263_4nprb352.jpg {'华为BBU5900'} 2
# 100000263_c086pphp.jpg {'中兴V9200'} 1
# 100000263_nex7a6at.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_73p4i1v0.jpg {'爱立信BB6630'} 1
# 100000263_p03m5ags.jpg {'爱立信BB6630'} 1
# 100000263_mmf8w646.jpg {'华为BBU5900'} 1
# 100000263_f0ur767v.jpg {'爱立信BB6630'} 3
# 100000263_0ea68y47.jpg {'爱立信BB6630'} 2
# 100000263_ycur6ojj.jpg {'中兴V9200'} 1
# 100000263_m8b32fe4.jpg {'中兴B8300', '华为BBU3900'} 2
# 100000263_sry3hv61.jpg {'中兴V9200'} 1
# 100000263_o6eiikm6.jpg {'中兴V9200'} 1
# 100000263_w0827k40.jpg {'中兴V9200'} 1
# 100000263_700dg1gc.jpg {'华为BBU5900'} 1
# 100000263_ymc177yf.jpg {'中兴V9200'} 1
# 100000263_571v5ha6.jpg {'爱立信BB6630'} 1
# 100000263_wjkxmg35.jpg {'中兴V9200'} 1
# 100000263_qbs641s4.jpg {'华为BBU5900'} 1
# 100000263_3gt8rice.jpg {'华为BBU5900'} 1
# 100000263_b642ksyh.jpg {'华为BBU5900'} 1
# 100000263_67x0u8xd.jpg {'爱立信BB6630'} 1
# 100000263_wiwo4jfw.jpg {'爱立信BB6630'} 1
# 100000263_5t160y12.jpg {'中兴V9200'} 1
# 100000263_yfp71806.jpg {'爱立信BB6630'} 1
# 100000263_5l66jql1.jpg {'中兴V9200'} 1
# 100000263_tq6e84a4.jpg {'中兴V9200'} 1
# 100000263_37hu4fex.jpg {'爱立信BB6630'} 1
# 100000263_0q80xncw.jpg {'华为BBU5900'} 1
# 100000263_3jfp48wo.jpg {'中兴V9200'} 1
# 100000263_17s36g87.jpg {'爱立信BB6630'} 1
# 100000263_6274t51c.jpg {'华为BBU5900'} 1
# 100000263_wk603g8m.jpg {'爱立信BB6630'} 2
# 100000263_1i556ylj.jpg {'华为BBU5900'} 2
# 100000263_4gw12h24.jpg {'爱立信BB6630'} 2
# 100000263_8426oylv.jpg {'华为BBU5900'} 2
# 100000263_d8tne737.jpg {'中兴V9200'} 2
# 100000263_yy3y68n2.jpg {'中兴V9200'} 1
# 100000263_2t6lp288.jpg {'爱立信BB6630'} 1
# 100000263_o1rcjoh6.jpg {'华为BBU5900'} 1
# 100000263_pjg67s43.jpg {'诺基亚 Airscale', '爱立信BB6630'} 2
# 100000263_vkt57ei0.jpg {'中兴V9200'} 1
# 100000263_s7hgbj5e.jpg {'华为BBU5900'} 1
# 100000263_w1nb34p1.jpg {'华为BBU5900'} 1
# 100000263_3r5g7404.jpg {'中兴V9200'} 1
# 100000263_fpp0s2uy.jpg {'爱立信BB6648'} 1
# 100000263_1kddy5sm.jpg {'中兴V9200'} 1
# 100000263_um6846l2.jpg {'华为BBU5900'} 1
# 100000263_gh411uu4.jpg {'华为BBU5900'} 1
# 100000263_568f243e.jpg {'中兴V9200'} 1
# 100000263_yu6vlfr1.jpg {'华为BBU5900'} 1
# 100000263_5va5gvd2.jpg {'爱立信BB6630'} 1
# 100000263_hu328p8n.jpg {'华为BBU3910'} 1
# 100000263_yabrr5h3.jpg {'华为BBU5900'} 1
# 100000263_7s32cnyt.jpg {'中兴V9200'} 1
# 100000263_4p2qn2q2.jpg {'中兴V9200'} 1
# 100000263_4ttty061.jpg {'中兴V9200'} 1
# 100000263_42qaa4dt.jpg {'中兴V9200'} 1
# 100000263_y8ya5pnr.jpg {'中兴V9200'} 1
# 100000263_16123qb7.jpg {'中兴V9200'} 1
# 100000263_6j6ee844.jpg {'中兴V9200'} 1
# 100000263_ok0q0hu0.jpg {'爱立信BB6630'} 1
# 100000263_364i6r51.jpg {'中兴V9200'} 1
# 100000263_mj022d30.jpg {'中兴V9200'} 1
# 100000263_w0f317p4.jpg {'华为BBU5900'} 1
# 100000263_1y1cwnif.jpg {'华为BBU5900'} 1
# 100000263_jev8a53p.jpg {'华为BBU5900'} 1
# 100000263_54vnibke.jpg {'中兴V9200'} 1
# 100000263_p7o64335.jpg {'中兴V9200'} 1
# 100000263_fiu42f8a.jpg {'华为BBU3900'} 1
# 100000263_qalgd52w.jpg {'华为BBU5900'} 1
# 100000263_youm000d.jpg {'中兴V9200'} 1
# 100000263_2t8qcl56.jpg {'中兴V9200'} 1
# 100000263_4r0y52sa.jpg {'爱立信BB6630'} 1
# 100000263_b362qj0q.jpg {'华为BBU5900'} 1
# 100000263_3qd52qb2.jpg {'爱立信BB6630'} 2
# 100000263_7yndx473.jpg {'中兴V9200'} 1
# 100000263_t6k7i6cj.jpg {'华为BBU5900'} 1
# 100000263_uh88m04w.jpg {'爱立信BB6630'} 1
# 100000263_o21csj16.jpg {'中兴V9200'} 1
# 100000263_p45js447.jpg {'爱立信BB6630'} 3
# 100000263_xh4438v2.jpg {'中兴V9200'} 1
# 100000263_5yn3uash.jpg {'爱立信BB6630'} 1
# 100000263_cyd0l4ai.jpg {'华为BBU5900'} 1
# 100000263_k0ao563r.jpg {'中兴V9200'} 1
# 100000263_838cs051.jpg {'爱立信BB6630'} 1
# 100000263_51o08f04.jpg {'华为BBU5900'} 1
# 100000263_3q181428.jpg {'华为BBU5900'} 1
# 100000263_cjf0p80d.jpg {'中兴V9200'} 1
# 100000263_w434r5mi.jpg {'中兴V9200'} 1
# 100000263_qhqq86br.jpg {'中兴V9200'} 1
# 100000263_6lb4154r.jpg {'华为BBU3910', '华为BBU5900'} 5
# 100000263_umo18c88.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_8vqrov12.jpg {'中兴V9200'} 1
# 100000263_ocyd2y14.jpg {'中兴V9200'} 1
# 100000263_w1lt07t7.jpg {'爱立信BB6630'} 1
# 100000263_w2htb41h.jpg {'华为BBU5900'} 1
# 100000263_sve81p74.jpg {'中兴V9200'} 1
# 100000263_sv2hq401.jpg {'华为BBU5900'} 1
# 100000263_7c2dqnnw.jpg {'华为BBU3910'} 1
# 100000263_71sw06s0.jpg {'中兴V9200'} 1
# ...
# 100000263_p08dk6y3.jpg {'中兴V9200'} 1
# 100000263_b366w6p7.jpg {'爱立信BB6630'} 1
# 100000263_we52ga7a.jpg {'中兴V9200'} 1
# 100000263_sf565u50.jpg {'中兴V9200'} 1
# 100000263_6r4lfm3q.jpg {'中兴V9200'} 1
# 100000263_pwu464j1.jpg {'中兴V9200'} 1
# 100000263_5nipa5jj.jpg {'中兴V9200'} 2
# 100000263_2x25745t.jpg {'华为BBU5900'} 1
# 100000263_50m376dm.jpg {'爱立信BB6630'} 2
# 100000263_ks01ef34.jpg {'中兴V9200'} 2
# 100000263_36338sok.jpg {'中兴V9200'} 1
# 100000263_614g8wss.jpg {'华为BBU5900'} 1
# 100000263_qkx436li.jpg {'爱立信BB6630'} 1
# 100000263_6pcjje7c.jpg {'中兴V9200'} 1
# 100000263_518l0acu.jpg {'华为BBU5900'} 1
# 100000263_w7hw872j.jpg {'中兴V9200'} 1
# 100000263_mc7ol5jy.jpg {'中兴V9200'} 1
# 100000263_04fo3gfb.jpg {'中兴V9200'} 1
# 100000263_c738p0fu.jpg {'中兴V9200'} 1
# 100000263_cp3pj2i6.jpg {'爱立信BB6630'} 1
# 100000263_x5jg8u43.jpg {'爱立信BB6648'} 2
# 100000263_6s2h873m.jpg {'中兴V9200'} 1
# 100000263_e8pp85bs.jpg {'诺基亚 FSIH'} 1
# 100000263_p4hh3e80.jpg {'华为BBU5900'} 1
# 100000263_u2fr1m18.jpg {'华为BBU5900'} 1
# 100000263_kba30848.jpg {'爱立信BB6630'} 1
# 100000263_23560ef6.jpg {'中兴V9200'} 2
# 100000263_wy73244d.jpg {'华为BBU5900'} 1
# 100000263_cq3dpj1x.jpg {'中兴V9200'} 1
# 100000263_xx853232.jpg {'中兴V9200'} 1
# 100000263_j83e57xa.jpg {'爱立信BB6630'} 2
# 100000263_pmok3ebo.jpg {'华为BBU5900'} 1
# 100000263_836y172q.jpg {'华为BBU5900'} 1
# 100000263_51vn71nl.jpg {'爱立信BB6630'} 1
# 100000263_ab36775c.jpg {'华为BBU5900'} 1
# 100000263_iw3h1cvq.jpg {'中兴V9200'} 1
# 100000263_ru3yd150.jpg {'爱立信BB6630'} 2
# 100000263_7o6l1755.jpg {'爱立信BB6630'} 1
# 100000263_r276f04o.jpg {'中兴V9200'} 1
# 100000263_4205ibfo.jpg {'华为BBU5900'} 1
# 100000263_oc1r26bs.jpg {'华为BBU5900'} 1
# 100000263_bwrh58r0.jpg {'爱立信BB6630'} 2
# 100000263_77v655ah.jpg {'华为BBU5900'} 1
# 100000263_kru65e3e.jpg {'中兴V9200'} 1
# 100000263_4u8446n5.jpg {'爱立信BB6630'} 1
# 100000263_h5i788rr.jpg {'华为BBU5900'} 1
# 100000263_4m6cen68.jpg {'中兴B8300'} 1
# 100000263_08tpekr3.jpg {'华为BBU5900'} 1
# 100000263_53eoe841.jpg {'爱立信BB6630'} 3
# 100000263_mw5yj6pr.jpg {'爱立信BB6648'} 1
# 100000263_45a24s58.jpg {'华为BBU5900'} 1
# 100000263_5fws4ig1.jpg {'爱立信BB6648'} 2
# 100000263_6367vxu3.jpg {'爱立信BB6630'} 1
# 100000263_y05wl6mc.jpg {'中兴V9200'} 1
# 100000263_43xpc336.jpg {'爱立信BB6630'} 3
# 100000263_e5lla6if.jpg {'爱立信BB6630'} 3
# 100000263_ow3fnmi1.jpg {'华为BBU5900'} 1
# 100000263_qk515pa8.jpg {'华为BBU5900'} 1
# 100000263_ujf151va.jpg {'华为BBU5900'} 1
# 100000263_5ig5v841.jpg {'爱立信BB6630'} 1
# 100000263_nt5c1544.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_0c1gt823.jpg {'爱立信BB6630'} 1
# 100000263_rddpu5d1.jpg {'爱立信BB6648'} 1
# 100000263_y6q1pwhk.jpg {'爱立信BB6630'} 3
# 100000263_tgl0u0v5.jpg {'中兴V9200'} 1
# 100000263_8lh5106e.jpg {'爱立信BB6630'} 2
# 100000263_85a4nq42.jpg {'中兴V9200'} 1
# 100000263_54401xv3.jpg {'华为BBU5900'} 1
# 100000263_68r46k0g.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_uck44221.jpg {'诺基亚 Airscale'} 2
# 100000263_q8264ts4.jpg {'爱立信BB6630'} 3
# 100000263_oo05s8a6.jpg {'中兴V9200'} 1
# 100000263_3175l2vs.jpg {'中兴V9200'} 1
# 100000263_jiic46vm.jpg {'华为BBU5900'} 1
# 100000263_2i7dk40a.jpg {'中兴V9200'} 1
# 100000263_t746e7hl.jpg {'中兴V9200'} 1
# 100000263_43203t8y.jpg {'爱立信BB6630'} 1
# 100000263_tuj756kq.jpg {'华为BBU5900'} 1
# 100000263_40o71g4c.jpg {'华为BBU5900'} 1
# 100000263_se16e5jf.jpg {'华为BBU5900'} 2
# 100000263_8b23e1x7.jpg {'爱立信BB6630'} 1
# 100000263_rej3o38s.jpg {'爱立信BB6630'} 1
# 100000263_xkic5s03.jpg {'爱立信BB6630'} 1
# 100000263_yrhwwou7.jpg {'华为BBU5900'} 1
# 100000263_441ae64u.jpg {'华为BBU5900'} 1
# 100000263_lp57r1vx.jpg {'华为BBU5900'} 1
# 100000263_h43epv2y.jpg {'中兴V9200'} 1
# 100000263_belu6qym.jpg {'中兴V9200'} 1
# 100000263_33052l1u.jpg {'中兴V9200'} 1
# 100000263_u262i1l7.jpg {'爱立信BB6630'} 3
# 100000263_ab7b5r67.jpg {'爱立信BB6648'} 1
# 100000263_qmebve20.jpg {'中兴V9200'} 1
# 100000263_7ipoys76.jpg {'中兴V9200'} 1
# 100000263_h204n2lc.jpg {'华为BBU5900'} 1
# 100000263_2t80y00o.jpg {'中兴V9200'} 1
# 100000263_e060758t.jpg {'华为BBU5900'} 1
# 100000263_guoa876u.jpg {'华为BBU5900'} 1
# 100000263_3atjmrbp.jpg {'中兴V9200'} 1
# 100000263_qr48cf27.jpg {'中兴V9200'} 1
# 100000263_ql4e0r02.jpg {'诺基亚 FSIH'} 1
# 100000263_0b0s86qs.jpg {'中兴V9200'} 1
# 100000263_s73fpx44.jpg {'华为BBU5900'} 1
# 100000263_24d8nkh5.jpg {'中兴V9200'} 1
# 100000263_4cd0302a.jpg {'爱立信BB6630'} 2
# 100000263_2op74pfk.jpg {'华为BBU5900'} 1
# 100000263_457rc238.jpg {'爱立信BB6648'} 1
# 100000263_x8m2eg38.jpg {'华为BBU5900'} 1
# 100000263_u824e8iq.jpg {'华为BBU5900'} 1
# 100000263_8405v318.jpg {'华为BBU5900'} 1
# 100000263_p62504cr.jpg {'爱立信BB6630'} 1
# 100000263_456021cm.jpg {'爱立信BB6648'} 1
# 100000263_74juf5f3.jpg {'爱立信BB6630'} 3
# 100000263_6574671y.jpg {'中兴V9200'} 1
# 100000263_3wax3h64.jpg {'中兴V9200'} 2
# 100000263_p0r1tma7.jpg {'华为BBU5900'} 1
# 100000263_8735y4no.jpg {'中兴V9200'} 1
# 100000263_1a3d30ml.jpg {'爱立信BB6630'} 1
# 100000263_f7nub8s7.jpg {'中兴V9200'} 1
# 100000263_616857fj.jpg {'爱立信BB6630'} 1
# 100000263_007rpm76.jpg {'爱立信BB6648'} 2
# 100000263_87l2w014.jpg {'华为BBU5900'} 1
# 100000263_3k5vov08.jpg {'中兴V9200'} 1
# 100000263_42m78r8u.jpg {'华为BBU5900'} 1
# 100000263_o8pt2vcl.jpg {'华为BBU5900'} 1
# 100000263_l54ehmet.jpg {'中兴V9200'} 1
# 100000263_hhmlwx0n.jpg {'爱立信BB6630'} 3
# 100000263_06cf6dim.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_2omm7v3j.jpg {'中兴V9200'} 1
# 100000263_7a80j8w8.jpg {'爱立信BB6630'} 1
# 100000263_60tkesu0.jpg {'爱立信BB6630'} 1
# 100000263_71f8brm0.jpg {'爱立信BB6630'} 1
# 100000263_12g703y8.jpg {'爱立信BB6630'} 1
# 100000263_n4v6fy43.jpg {'诺基亚 Airscale', '诺基亚 FSIH'} 2
# 100000263_5ue5g0kc.jpg {'爱立信BB6630'} 2
# 100000263_5gs3587b.jpg {'华为BBU5900'} 1
# 100000263_wlap4ck3.jpg {'华为BBU5900'} 1
# 100000263_3sbwa2y7.jpg {'爱立信BB6648'} 2
# 100000263_o7b784a4.jpg {'中兴V9200'} 1
# 100000263_mrtg5vbf.jpg {'中兴V9200'} 1
# 100000263_wp522yet.jpg {'爱立信BB6630'} 1
# 100000263_am0xgh6q.jpg {'爱立信BB6630'} 2
# 100000263_mjl6w5jc.jpg {'华为BBU5900'} 1
# 100000263_h4j0hslj.jpg {'华为BBU5900'} 1
# 100000263_xfcn5rny.jpg {'华为BBU5900'} 1
# 100000263_em3c186k.jpg {'中兴V9200'} 1
# 100000263_nl2rgmwg.jpg {'爱立信BB6630'} 3
# 100000263_3om4gyf1.jpg {'中兴V9200'} 1
# 100000263_2m4261j4.jpg {'中兴V9200'} 1
# 100000263_vlr1310o.jpg {'爱立信BB6630'} 1
# 100000263_ifymkk3k.jpg {'爱立信BB6630'} 1
# 100000263_3glbrgkb.jpg {'中兴V9200'} 1
# 100000263_oeo6l61f.jpg {'爱立信BB6630'} 1
# 100000263_3c2r2505.jpg {'中兴V9200'} 1
# 100000263_2171tu8c.jpg {'华为BBU5900'} 1
# 100000263_to540t33.jpg {'中兴V9200'} 1
# 100000263_mype3l48.jpg {'爱立信BB6630'} 1
# 100000263_o5b03q82.jpg {'中兴V9200'} 1
# 100000263_o3o85dem.jpg {'华为BBU5900'} 1
# 100000263_666y40m3.jpg {'爱立信BB6630'} 2
# 100000263_3m4ssc1c.jpg {'华为BBU5900'} 1
# 100000263_uc148d4n.jpg {'华为BBU5900'} 1
# 100000263_0c2arq00.jpg {'诺基亚 FSIH'} 1
# 100000263_048jld1j.jpg {'爱立信BB6648'} 1
# 100000263_bbdp78r6.jpg {'诺基亚 FSIH'} 1
# 100000263_j385h8be.jpg {'中兴V9200'} 1
# 100000263_04h7odft.jpg {'爱立信BB6630'} 1
# 100000263_ed866g6n.jpg {'华为BBU5900'} 1
# 100000263_db0vwa83.jpg {'华为BBU5900'} 1
# 100000263_i51834h6.jpg {'中兴V9200'} 1
# 100000263_jxm7r5a7.jpg {'中兴V9200'} 1
# 100000263_o1p58k55.jpg {'中兴V9200'} 1
# 100000263_4l8a6415.jpg {'中兴V9200'} 1
# 100000263_i1bxfgp8.jpg {'华为BBU5900'} 1
# 100000263_71jva552.jpg {'爱立信BB6630'} 2
# 100000263_5m4p4t78.jpg {'中兴V9200'} 1
# 100000263_080v388n.jpg {'中兴V9200'} 1
# 100000263_66d0c6xc.jpg {'中兴V9200'} 1
# 100000263_q7rq7rn6.jpg {'中兴V9200'} 1
# 100000263_jr77ahcg.jpg {'华为BBU5900'} 1
# 100000263_d28o1oij.jpg {'华为BBU5900'} 1
# 100000263_6r4k01qa.jpg {'中兴V9200'} 1
# 100000263_8sj3mqt2.jpg {'爱立信BB6630'} 3
# 100000263_58725vi2.jpg {'爱立信BB6630'} 3
# 100000263_jl0bx43w.jpg {'爱立信BB6630'} 1
# 100000263_5m307d65.jpg {'爱立信BB6630'} 2
# 100000263_7tx57y7n.jpg {'华为BBU5900'} 1
# 100000263_3nob0jp1.jpg {'中兴V9200'} 1
# 100000263_k8cvya5o.jpg {'中兴V9200'} 1
# 100000263_imnmros7.jpg {'中兴V9200'} 3
# 100000263_35644a33.jpg {'华为BBU5900'} 1
# 100000263_4504i6q2.jpg {'爱立信BB6630'} 1
# 100000263_656ao778.jpg {'爱立信BB6630'} 3
# 100000263_36xak2gi.jpg {'爱立信BB6630'} 1
# 100000263_8bt64vty.jpg {'爱立信BB6630'} 1
# 100000263_33m41k45.jpg {'中兴V9200'} 1
# 100000263_u820sni4.jpg {'华为BBU5900'} 1
# 100000263_786g3fsi.jpg {'中兴V9200'} 1
# 100000263_bhy2uv7r.jpg {'中兴V9200'} 1
# 100000263_8vxi568s.jpg {'中兴V9200'} 1
# 100000263_vn0410x1.jpg {'华为BBU5900'} 1
# 100000263_p01225m2.jpg {'中兴V9200'} 1
# 100000263_tgfiqts5.jpg {'华为BBU5900'} 1
# 100000263_h1m61q4a.jpg {'华为BBU5900'} 1
# 100000263_k3e4mht8.jpg {'中兴V9200'} 1
# 100000263_048p51w4.jpg {'华为BBU5900'} 1
# 100000263_32swftot.jpg {'爱立信BB6630'} 1
# 100000263_nx21wbv7.jpg {'华为BBU5900'} 1
# 100000263_2m2tskn4.jpg {'中兴V9200'} 1
# 100000263_51ur40x1.jpg {'中兴V9200'} 1
# 100000263_db0g6pw0.jpg {'华为BBU5900'} 1
# 100000263_7ga05p37.jpg {'诺基亚 Airscale', '诺基亚 FSIH'} 2
# 100000263_a488lc87.jpg {'华为BBU5900'} 1
# 100000263_6h44061y.jpg {'中兴V9200'} 1
# 100000263_n26mcr4j.jpg {'爱立信BB6648'} 3
# 100000263_c3218xpl.jpg {'华为BBU5900'} 1
# 100000263_s88et7x3.jpg {'中兴V9200'} 1
# 100000263_6lry65x0.jpg {'华为BBU5900'} 1
# 100000263_g07v1p6i.jpg {'爱立信BB6630'} 2
# 100000263_w4abjndk.jpg {'中兴V9200'} 1
# 100000263_c8n1q1q7.jpg {'中兴V9200'} 1
# 100000263_k543d677.jpg {'中兴V9200'} 1
# 100000263_1jn3gx7k.jpg {'中兴V9200'} 1
# 100000263_f8ae3l24.jpg {'诺基亚 Airscale', '爱立信BB6630'} 4
# 100000263_wb876504.jpg {'爱立信BB6630'} 3
# 100000263_s1c764s8.jpg {'中兴V9200'} 1
# 100000263_6l6g25j7.jpg {'华为BBU5900'} 1
# 100000263_ir4rh7sy.jpg {'中兴V9200'} 1
# 100000263_i213c266.jpg {'华为BBU5900'} 1
# 100000263_12ag281n.jpg {'爱立信BB6648'} 1
# 100000263_004tb77v.jpg {'华为BBU5900'} 1
# 100000263_s308q67l.jpg {'中兴V9200'} 1
# 100000263_5n3623tk.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_4k4tfyg8.jpg {'中兴V9200'} 1
# 100000263_h8ex55r1.jpg {'爱立信BB6630'} 1
# 100000263_l7gyoi5t.jpg {'华为BBU5900'} 1
# 100000263_11e8eq1f.jpg {'爱立信BB6630'} 2
# 100000263_j1yskr3k.jpg {'中兴V9200'} 1
# 100000263_1yonedko.jpg {'爱立信BB6630'} 1
# 100000263_n30s21r6.jpg {'中兴V9200'} 1
# 100000263_w7spe844.jpg {'爱立信BB6630'} 2
# 100000263_6lx4ffs8.jpg {'华为BBU5900'} 1
# 100000263_l483qm5l.jpg {'华为BBU5900'} 1
# 100000263_lyefqsyk.jpg {'诺基亚 Airscale', '爱立信BB6630'} 2
# 100000263_we5ecppb.jpg {'爱立信BB6630', '爱立信BB6648'} 2
# 100000263_cdr1ykrw.jpg {'诺基亚 Airscale'} 1
# 100000263_y555c5wt.jpg {'中兴V9200'} 1
# 100000263_35204027.jpg {'中兴V9200'} 1
# 100000263_kvqmuc25.jpg {'爱立信BB6630'} 1
# 100000263_4stiwl42.jpg {'中兴B8300'} 1
# 100000263_op6164g1.jpg {'华为BBU5900'} 1
# 100000263_y6olynd2.jpg {'诺基亚 Airscale', '爱立信BB6630'} 2
# 100000263_0vq7l521.jpg {'中兴V9200'} 1
# 100000263_db22u4q3.jpg {'爱立信BB6630'} 1
# 100000263_8w8el4qh.jpg {'中兴V9200'} 1
# 100000263_6hd2xw7b.jpg {'华为BBU3910', '爱立信BB6630'} 3
# 100000263_464x3qjv.jpg {'中兴V9200'} 1
# 100000263_febic4t7.jpg {'中兴V9200'} 1
# 100000263_7jtvpw03.jpg {'中兴B8300'} 1
# 100000263_7yiw0io8.jpg {'中兴V9200'} 1
# 100000263_n10oy02b.jpg {'中兴B8300'} 1
# 100000263_710dmt0a.jpg {'中兴V9200'} 1
# 100000263_65cbdof4.jpg {'华为BBU5900'} 1
# 100000263_02vjcv7w.jpg {'华为BBU5900'} 1
# 100000263_511b4l38.jpg {'中兴V9200'} 1
# 100000263_5qbmig12.jpg {'华为BBU5900'} 1
# 100000263_sbptv3m0.jpg {'爱立信BB6630'} 1
# 100000263_72fjty5k.jpg {'中兴V9200'} 1
# 100000263_5uly2n8m.jpg {'中兴V9200'} 1
# 100000263_277cqb17.jpg {'爱立信BB6630'} 2
# 100000263_cm1flx4s.jpg {'华为BBU5900'} 1
# 100000263_6u4o6e60.jpg {'中兴V9200'} 1
# 100000263_inkr14qp.jpg {'爱立信BB6630'} 2
# 100000263_d8o84v3o.jpg {'爱立信BB6630'} 1
# 100000263_2h0qmgb3.jpg {'中兴V9200'} 1
# 100000263_823tv1g1.jpg {'华为BBU5900'} 1
# 100000263_4382x50g.jpg {'爱立信BB6630'} 6
# 100000263_eg2pof35.jpg {'中兴B8300'} 1
# 100000263_6276y41x.jpg {'华为BBU5900'} 2
# 100000263_y004x313.jpg {'中兴V9200'} 1
# 100000263_8xdik27m.jpg {'中兴V9200'} 1
# 100000263_ti0wrc62.jpg {'华为BBU5900'} 1
# 100000263_wb3085bk.jpg {'中兴V9200'} 1
# 100000263_b7ub86ed.jpg {'中兴V9200'} 1
# 100000263_06g5p14p.jpg {'中兴V9200'} 1
# 100000263_nfun4vkv.jpg {'中兴V9200'} 1
# 100000263_0d6r14v7.jpg {'中兴V9200'} 1
# 100000263_em0085a0.jpg {'中兴V9200'} 1
# 100000263_7n8c4vv8.jpg {'爱立信BB6630'} 2
# 100000263_3hqeud0n.jpg {'华为BBU5900'} 1
# 100000263_235pa3l6.jpg {'中兴V9200'} 1
# 100000263_0y83gxya.jpg {'中兴V9200'} 1
# 100000263_20x74772.jpg {'爱立信BB6630'} 2
# 100000263_evfjd8ug.jpg {'中兴V9200'} 1
# 100000263_ffg8majg.jpg {'中兴V9200'} 1
# 100000263_60wabk0x.jpg {'爱立信BB6630'} 3
# 100000263_kp4lt4t5.jpg {'中兴V9200'} 1
# 100000263_8pttmhcd.jpg {'华为BBU3910'} 1
# 100000263_ydt75pl2.jpg {'华为BBU5900'} 1
# 100000263_n35114l5.jpg {'华为BBU5900'} 1
# 100000263_cg35111v.jpg {'诺基亚 FSIH'} 1
# 100000263_6h54qv24.jpg {'中兴V9200'} 1
# 100000263_j5ofo51e.jpg {'华为BBU5900'} 1
# 100000263_3h2b18nq.jpg {'华为BBU5900'} 1
# 100000263_77od10b1.jpg {'爱立信BB6630', '诺基亚 FSIH'} 2
# 100000263_686jcpr2.jpg {'中兴V9200'} 1
# 100000263_yla4172e.jpg {'爱立信BB6630'} 1
# 100000263_3qlc0bwe.jpg {'爱立信BB6630'} 1
# 100000263_bn1hg516.jpg {'中兴V9200'} 1
# 100000263_tu2x241c.jpg {'中兴V9200'} 3
# 100000263_23l28l42.jpg {'中兴V9200'} 1
# 100000263_0554082b.jpg {'华为BBU5900'} 1
# 100000263_3d3bulvk.jpg {'中兴V9200'} 1
# 100000263_eg74n02l.jpg {'华为BBU5900'} 1
# 100000263_l3633j45.jpg {'华为BBU5900'} 1
# 100000263_i0cf21d7.jpg {'爱立信BB6648'} 1
# 100000263_4qj342aa.jpg {'中兴V9200', '中兴B8300'} 2
# 100000263_0pr54237.jpg {'爱立信BB6630', '爱立信BB6648'} 4
# 100000263_c4117v81.jpg {'华为BBU3900'} 1
# 100000263_5yl2nkja.jpg {'华为BBU3910'} 1
# 100000263_chg60t5u.jpg {'华为BBU3910'} 1
# 100000263_v2227h3b.jpg {'诺基亚 Airscale', '诺基亚 FSIH'} 2
# 100000263_4781jr4v.jpg {'爱立信BB6630'} 1
# 100000263_q640vmk3.jpg {'中兴V9200'} 1
# 100000263_wqp7a245.jpg {'爱立信BB6630'} 4
# 100000263_25111787.jpg {'华为BBU5900'} 1
# 100000263_15q0n235.jpg {'中兴V9200'} 1
# 100000263_yr7f28x1.jpg {'华为BBU5900'} 1
# 100000263_qs73yb71.jpg {'爱立信BB6630'} 1
# 100000263_c46t016y.jpg {'爱立信BB6630'} 1
# 100000263_6i7laihx.jpg {'爱立信BB6630'} 1
# 100000263_38k8i612.jpg {'华为BBU5900'} 1
# 100000263_8iyv6e70.jpg {'中兴V9200'} 1
# 100000263_7g3v3xcm.jpg {'爱立信BB6630'} 2
# 100000263_1u4y0cj1.jpg {'中兴V9200'} 1
# 100000263_wua2matb.jpg {'中兴V9200'} 1
# 100000263_x2e3qj1c.jpg {'华为BBU5900'} 1
# 100000263_v10rh130.jpg {'爱立信BB6630'} 1
# 100000263_s74f01sj.jpg {'爱立信BB6630'} 2
# 100000263_4qce5w1c.jpg {'爱立信BB6630'} 3
# 100000263_543ssy7h.jpg {'爱立信BB6630', '爱立信BB6648'} 3
# 100000263_vgc710lq.jpg {'华为BBU5900'} 1
# 100000263_o2fe48hi.jpg {'爱立信BB6630'} 1
# 100000263_1rj00xxj.jpg {'华为BBU5900'} 1
# 100000263_ei112303.jpg {'中兴V9200'} 1
# 100000263_5o83e03t.jpg {'华为BBU5900'} 1
# 100000263_2w5axq04.jpg {'华为BBU5900'} 1
# 100000263_0armj3wv.jpg {'爱立信BB6630'} 2
# 100000263_agf2suay.jpg {'中兴V9200'} 1
# 100000263_0y8l68ml.jpg {'中兴V9200'} 1
# 100000263_yjsofp1c.jpg {'华为BBU5900'} 1
# 100000263_w0if4g30.jpg {'爱立信BB6630'} 2
# 100000263_m4u7u5h2.jpg {'中兴V9200'} 1
# 100000263_22r37lkc.jpg {'中兴V9200'} 1
# 100000263_j5j83sc0.jpg {'中兴V9200'} 1
# 100000263_0347c2f4.jpg {'爱立信BB6630'} 2
# 100000263_668883c6.jpg {'中兴V9200'} 1
# 100000263_h3x0sq24.jpg {'爱立信BB6630'} 1
# 100000263_c8fsxle2.jpg {'华为BBU3910'} 1
# 100000263_r24r5lra.jpg {'爱立信BB6630'} 1
# 100000263_ifl6w638.jpg {'爱立信BB6630'} 2
# 100000263_0u513f23.jpg {'中兴V9200'} 1
# 100000263_5s20h38c.jpg {'华为BBU5900'} 1
# 100000263_61i7646s.jpg {'爱立信BB6630'} 1
# 100000263_1pht428k.jpg {'中兴V9200'} 1
# 100000263_d885p56c.jpg {'华为BBU5900'} 1
# 100000263_87rbiruq.jpg {'中兴V9200'} 1
# 100000263_h38hadr6.jpg {'华为BBU5900'} 1
# 100000263_li02230c.jpg {'中兴V9200'} 1
# 100000263_1g4uwaog.jpg {'中兴V9200'} 1
# 100000263_qyf8t3b6.jpg {'华为BBU5900'} 1
# 100000263_5k4jc4u1.jpg {'中兴V9200'} 1
# 100000263_222aip3k.jpg {'中兴V9200'} 1
# 100000263_b6w53p05.jpg {'爱立信BB6630'} 1
# 100000263_5b6c43m7.jpg {'华为BBU5900'} 1
# 100000263_6df62ii3.jpg {'华为BBU3910', '中兴V9200'} 2
# 100000263_l306tjx0.jpg {'中兴V9200'} 1
# 100000263_2o715xo1.jpg {'中兴V9200'} 1
# 100000263_nsf2o26l.jpg {'华为BBU5900'} 1
# 100000263_q11be2as.jpg {'爱立信BB6630'} 2
# 100000263_78e0g3o3.jpg {'中兴V9200'} 1
# 100000263_kj236i53.jpg {'华为BBU5900'} 1
# 100000263_524o618r.jpg {'爱立信BB6630'} 3
# 100000263_5j6kvp3o.jpg {'华为BBU5900'} 1
# 100000263_76x5f6sv.jpg {'中兴V9200'} 1
# 100000263_86p411nv.jpg {'中兴V9200'} 1
# 100000263_81u01nfr.jpg {'爱立信BB6630'} 1
# 100000263_1rior1ry.jpg {'爱立信BB6630'} 3
# 100000263_b1m07ui4.jpg {'爱立信BB6630'} 1
# 100000263_86jfihc4.jpg {'中兴V9200'} 1
# 100000263_qa01neox.jpg {'中兴V9200'} 1
# 100000263_bb212bs2.jpg {'华为BBU3910'} 1
# 100000263_1mmq27os.jpg {'中兴V9200'} 1
# 100000263_th4678lo.jpg {'华为BBU5900'} 1
# 100000263_47nki2d2.jpg {'中兴V9200'} 1
# 100000263_mbu6lu4d.jpg {'爱立信BB6630'} 2
# 100000263_o0qft1oa.jpg {'华为BBU5900'} 1
# 100000263_64v73k3p.jpg {'华为BBU5900'} 1
# 100000263_32186336.jpg {'中兴V9200'} 1
# 100000263_ty68c161.jpg {'华为BBU5900'} 1
# 100000263_m8w81023.jpg {'中兴V9200'} 1
# 100000263_ldfs61lm.jpg {'中兴V9200'} 1
# 100000263_s54gq4s8.jpg {'华为BBU5900'} 1
# 100000263_3yi37nkk.jpg {'中兴V9200'} 1
# 100000263_2v25v075.jpg {'爱立信BB6630'} 1
# 100000263_10n5f15t.jpg {'中兴V9200'} 1
# 100000263_g164x052.jpg {'中兴V9200'} 1
# 100000263_s42lc615.jpg {'华为BBU3910', '华为BBU5900'} 2
# 100000263_s4h2y0br.jpg {'爱立信BB6630'} 3
# 100000263_78338hh8.jpg {'爱立信BB6630'} 1
# 100000263_8087026g.jpg {'华为BBU5900'} 1
# 100000263_dt3y87o6.jpg {'华为BBU5900'} 1
# 100000263_18v4b03m.jpg {'爱立信BB6630'} 1

# %%
# Allocate to each set averagely within each device
index = 0
k = 5 # k-fold cross validation
counter = np.zeros(k,)
for txt in txtlist:
    with open(txtSavePath + txt + '.txt', 'r') as f:
        filelist = f.readlines()
    for file in filelist:
        partitionSet[index % k].write(file)
        counter[index % k] += 1
        index += 1
    f.close()
    print('Partitioned ' + txt, f', {index} files in total.')
    print(counter)
    counter = np.zeros(k,)
    index = 0
for set_i in partitionSet:
    set_i.close()
# Out:
# Partitioned BBU3900 , 13 files in total.
# [3. 3. 3. 2. 2.]
# Partitioned FSIH , 20 files in total.
# [4. 4. 4. 4. 4.]
# Partitioned B8300 , 32 files in total.
# [7. 7. 6. 6. 6.]
# Partitioned Airscale , 31 files in total.
# [7. 6. 6. 6. 6.]
# Partitioned BBU3910 , 60 files in total.
# [12. 12. 12. 12. 12.]
# Partitioned BB6648 , 78 files in total.
# [16. 16. 16. 15. 15.]
# Partitioned BBU5900 , 758 files in total.
# [152. 152. 152. 151. 151.]
# Partitioned BB6630 , 623 files in total.
# [125. 125. 125. 124. 124.]
# Partitioned V9200 , 1078 files in total.
# [216. 216. 216. 215. 215.]

# %%
# Augment train sets and send to yolov5 dataset
k = 5 # k-fold cross validation
test_set = 5 # awaits modification
n = 2 # augment strength constant
train_set = []
for i in range(k):
    train_set.append(str(i + 1))
train_set.pop(test_set - 1)
print('test: ', test_set, ', train: ', train_set)

counter = np.zeros(9,)
for index in train_set:
    with open(partitionSet[int(index) - 1], 'r') as f:
        imgList = f.readlines()
        f.close()
    for image in imgList:
        imgName = image.replace('\n', '')
        annoName = imgName.replace('.jpg','.xml').replace('image', 'xml')
        if annoName == annoPath + '.ipynb_checkpoints': continue
        dom = xml.dom.minidom.parse(annoName)
        collection = dom.documentElement
        objectlist = collection.getElementsByTagName('object')

        devices = []
        for obj in objectlist:
            if obj.getElementsByTagName('name')[0].childNodes[0].data == '接地': continue
            if obj.getElementsByTagName('name')[0].childNodes[0].data == '接地线': continue
            type = obj.getElementsByTagName('type')[0].childNodes[0].data
            devices.append(type)

        if '华为BBU3900' in devices:
            times = min(50, round(216 / 3 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[0] += 1
            for i in range(times):
                counter[0] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '诺基亚 FSIH' in devices:
            times = min(50, round(216 / 4 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[1] += 1
            for i in range(times):
                counter[1] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '中兴B8300' in devices:
            times = min(50, round(216 / 6 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[2] += 1
            for i in range(times):
                counter[2] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '诺基亚 Airscale' in devices:
            times = min(50, round(216 / 6 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[3] += 1
            for i in range(times):
                counter[3] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '华为BBU3910' in devices:
            times = min(50, round(216 / 12 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[4] += 1
            for i in range(times):
                counter[4] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '爱立信BB6648' in devices:
            times = min(50, round(216 / 16 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[5] += 1
            for i in range(times):
                counter[5] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '华为BBU5900' in devices:
            times = min(50, round(216 / 152 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[6] += 1
            for i in range(times):
                counter[6] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '爱立信BB6630' in devices:
            times = min(50, round(216 / 125 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[7] += 1
            for i in range(times):
                counter[7] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
        elif '中兴V9200' in devices:
            times = min(50, round(216 / 216 * n))
            shutil.copy(imgName, imgDst)
            shutil.copy(annoName, annoDst)
            counter[8] += 1
            for i in range(times):
                counter[8] += 1
                newImgName = imgDst + imgName.replace('.jpg', f'_aug{i+1}.jpg').replace(imgPath, '')
                newAnnoName = annoDst + imgName.replace('.jpg', f'_aug{i+1}.xml').replace(imgPath, '')
                doAug(imgName, annoName, newImgName, newAnnoName)
print(counter)
# Out:
# test:  5 , train:  ['1', '2', '3', '4']
# [ 561.  816. 1326. 1275. 1776. 1764. 2428. 1996. 2589.]

# %%
# Send test set to yolov5 dataset
k = 5 # k-fold cross validation
test_set = 5 # awaits modification
train_set = []
for i in range(k):
    train_set.append(str(i + 1))
train_set.pop(test_set - 1)
print('test: ', test_set, ', train: ', train_set)


with open(partitionSet[test_set - 1], 'r') as f:
    imgList = f.readlines()
    f.close()
for image in imgList:
        imgName = image.replace('\n', '')
        annoName = imgName.replace('.jpg','.xml').replace('image', 'xml')
        if annoName == annoPath + '.ipynb_checkpoints': continue
        shutil.copy(imgName, imgDst)
        shutil.copy(annoName, annoDst)
# Out:
# test:  5 , train:  ['1', '2', '3', '4']

# %%
# !python /root/yolov5/split_train_val_test.py

# %%
# !python /root/yolov5/voc_label.py
# Out:
# /root

# %%
clear(['annotation', 'images', 'labels', 'partition/main'])#'annotation', 'images', 'labels', 'partition/main'

# %%
print(len(os.listdir(imgDst)), len(os.listdir(annoDst)))
print(len(os.listdir(root_dst_path + 'labels')))
# Out:
# 542 542
# 542

# %%
imgList = os.listdir(imgPath)
for image in imgList:
        imgName = imgPath + image
        annoName = annoPath + image.replace('.jpg', '.xml')
        if annoName == annoPath + '.ipynb_checkpoints': continue
        shutil.copy(imgName, imgDst)
        shutil.copy(annoName, annoDst)
